# %% [markdown]
# # Trust Pilot Webscraping
# Author: Stefanie Arlt

# %%
# import
import urllib.request
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
from bs4 import UnicodeDammit

# %% [markdown]
# ### Energy distributors operating in Germany
#
# 37 distributors in Germany are listed on two pages on the Trustpilot web site for the category of 'power supply company'.
#  - Page 1 with 20 entries.
#  - Page 2 with 17 entries.
#
# The standard sorting of the suppliers is "according to relevance". This filter shows all energy suppliers sorted by highest TrustScore and numbers of votes. In addition, the companies have to fulfill the following conditions, to ensure that the companies with the highest votes receive up-to-date customer feedback:
#  - The supplier needs to have received at least 25 evaluations in the last 12 months.
#  - The supplier must have the status "asking for evaluation".
#
# We would like to extract the name, score, number of votes and business location of each energy distributor.

# %%
# Store the url of the first page
url1_tp = "https://de.trustpilot.com/categories/electric_utility_company"
#Retrieve the HTML code of the page
page1 = urllib.request.urlopen(url1_tp)

# %%
# Store the url of the second page
url2_tp = "https://de.trustpilot.com/categories/electric_utility_company?page=2"
#Retrieve the HTML code of the page
page2 = urllib.request.urlopen(url2_tp)

# %%
# set HTML code as HTML file with parser
page1_soup = bs(page1, "html.parser")
page2_soup = bs(page2, "html.parser")

# %%
# first header on page 1
print(page1_soup.h1.text)
# Out:
# Spitzenreiter in der Kategorie Stromversorgungsunternehmen

# %%
# title of page 1
print(page1_soup.title.text)
# Out:
# Die besten Unternehmen in der Kategorie Stromversorgungsunternehmen auf Trustpilot

# %%
#number of children in page1_soup
len(list(page1_soup.descendants))
# Out:
# 6087

# %%
#Display lines with list of energy suppliers
page1_soup.prettify().splitlines()[1120:2000]
# Out:
# ['             </option>',
#  '             <option value="BY">',
#  '              Weißrussland',
#  '             </option>',
#  '             <option value="EH">',
#  '              Westsahara',
#  '             </option>',
#  '             <option value="CF">',
#  '              Zentralafrikanische Republik',
#  '             </option>',
#  '             <option value="CY">',
#  '              Zypern',
#  '             </option>',
#  '            </select>',
#  '            <svg class="icon_icon__ECGRl icon_appearance-default___4uy_" height="16px" viewbox="0 0 20 20" width="16px" xmlns="http://www.w3.org/2000/svg">',
#  '             <path d="m0 5 10 10L20 5z" fill-rule="evenodd">',
#  '             </path>',
#  '            </svg>',
#  '           </div>',
#  '           <form class="styles_wrapper__bsj8o styles_locationField__3Q3cb">',
#  '            <div class="styles_inputWrapper__8RN0V">',
#  '             <div class="styles_inputIcon___dEI8 styles_searchIcon__BqP9U">',
#  '              <svg class="icon_icon__ECGRl icon_appearance-subtle__9l3Sf" fill="inherit" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">',
#  '               <path clip-rule="evenodd" d="M3 6.75a3.75 3.75 0 1 1 7.5 0 3.75 3.75 0 0 1-7.5 0ZM6.75 2a4.75 4.75 0 1 0 2.987 8.444l3.91 3.91.707-.708-3.91-3.91A4.75 4.75 0 0 0 6.75 2Z" fill-rule="evenodd">',
#  '               </path>',
#  '              </svg>',
#  '             </div>',
#  '             <input aria-invalid="false" aria-label="Ort oder Postleitzahl" autocomplete="off" class="text-input_textInput__0GjCy text-input_textInput--l__SSx7a" data-search-input="true" maxlength="100" placeholder="Ort oder Postleitzahl" type="search" value=""/>',
#  '            </div>',
#  '           </form>',
#  '          </fieldset>',
#  '          <fieldset class="styles_wrapper__c1ZnQ styles_fieldset__uRF8r styles_companyStatusFilters__UiuRm">',
#  '           <legend class="typography_heading-xs__jSwUz typography_appearance-default__AAY17 styles_legend__cqrWG">',
#  '            Unternehmensstatus',
#  '           </legend>',
#  '           <div class="styles_fields__shgje">',
#  '            <label class="typography_default__hIMlQ typography_appearance-default__AAY17 styles_item__BrBDU">',
#  '             <span class="typography_default__hIMlQ typography_appearance-subtle__8_H2l styles_label__OSdvH">',
#  '              Verifiziert',
#  '              <span>',
#  '               <div class="styles_tooltipButton__IJUNJ">',
#  '                <svg class="icon_icon__ECGRl icon_appearance-default___4uy_" height="12px" viewbox="0 0 16 16" width="12px" xmlns="http://www.w3.org/2000/svg">',
#  '                 <path clip-rule="evenodd" d="M8 1a7 7 0 1 0 0 14A7 7 0 0 0 8 1ZM0 8a8 8 0 1 1 16 0A8 8 0 0 1 0 8Z" fill-rule="evenodd">',
#  '                 </path>',
#  '                 <path clip-rule="evenodd" d="M7.5 7h-.75V6H8.5v5.502h.75v1h-2.5v-1h.75V7ZM6.75 4a1 1 0 1 1 2 0 1 1 0 0 1-2 0Z" fill-rule="evenodd">',
#  '                 </path>',
#  '                </svg>',
#  '               </div>',
#  '              </span>',
#  '              <input class="checkbox_checkbox__yq_KY" data-verified-checkbox="true" type="checkbox"/>',
#  '             </span>',
#  '            </label>',
#  '            <label class="typography_default__hIMlQ typography_appearance-default__AAY17 styles_item__BrBDU">',
#  '             <span class="typography_default__hIMlQ typography_appearance-subtle__8_H2l styles_label__OSdvH">',
#  '              Profil beansprucht',
#  '              <span>',
#  '               <div class="styles_tooltipButton__IJUNJ">',
#  '                <svg class="icon_icon__ECGRl icon_appearance-default___4uy_" height="12px" viewbox="0 0 16 16" width="12px" xmlns="http://www.w3.org/2000/svg">',
#  '                 <path clip-rule="evenodd" d="M8 1a7 7 0 1 0 0 14A7 7 0 0 0 8 1ZM0 8a8 8 0 1 1 16 0A8 8 0 0 1 0 8Z" fill-rule="evenodd">',
#  '                 </path>',
#  '                 <path clip-rule="evenodd" d="M7.5 7h-.75V6H8.5v5.502h.75v1h-2.5v-1h.75V7ZM6.75 4a1 1 0 1 1 2 0 1 1 0 0 1-2 0Z" fill-rule="evenodd">',
#  '                 </path>',
#  '                </svg>',
#  '               </div>',
#  '              </span>',
#  '              <input class="checkbox_checkbox__yq_KY" data-claimed-checkbox="true" type="checkbox"/>',
#  '             </span>',
#  '            </label>',
#  '           </div>',
#  '          </fieldset>',
#  '         </div>',
#  '         <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv styles_desktop__BuH18 styles_asideItem__L0Qpz">',
#  '          <h2 class="typography_heading-xs__jSwUz typography_appearance-default__AAY17 styles_legend__cqrWG styles_header___ScaR">',
#  '           <span class="typography_heading-xs__jSwUz typography_appearance-default__AAY17">',
#  '            Ähnliche Kategorien',
#  '           </span>',
#  '           <button class="button_button__T34Lr button_appearance-link__ANr2s" data-toggle-all-related-categories-button-button="true" name="Toggle all related categories button" type="button">',
#  '            <span class="typography_body-m__xgxZ_ typography_appearance-action__9NNRY link_link__IZzHN link_notUnderlined__szqki">',
#  '             Alle anzeigen',
#  '            </span>',
#  '           </button>',
#  '          </h2>',
#  '          <ul class="styles_categories__Osvym">',
#  '           <li class="styles_category__bGrxO">',
#  '            <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-inherit__D7XqR link_link__IZzHN link_notUnderlined__szqki styles_categoryLink__9HVh5" href="/categories/power_plant" target="_self">',
#  '             <span>',
#  '              Elektrizitätswerk',
#  '             </span>',
#  '             <p class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l">',
#  '              3',
#  '             </p>',
#  '            </a>',
#  '           </li>',
#  '           <li class="styles_category__bGrxO">',
#  '            <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-inherit__D7XqR link_link__IZzHN link_notUnderlined__szqki styles_categoryLink__9HVh5" href="/categories/utility_contractor" target="_self">',
#  '             <span>',
#  '              Energieanbieter',
#  '             </span>',
#  '             <p class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l">',
#  '              54',
#  '             </p>',
#  '            </a>',
#  '           </li>',
#  '           <li class="styles_category__bGrxO">',
#  '            <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-inherit__D7XqR link_link__IZzHN link_notUnderlined__szqki styles_categoryLink__9HVh5" href="/categories/energy_equipment_and_solutions" target="_self">',
#  '             <span>',
#  '              Energieanlagen und -lösungen',
#  '             </span>',
#  '             <p class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l">',
#  '              48',
#  '             </p>',
#  '            </a>',
#  '           </li>',
#  '           <li class="styles_category__bGrxO">',
#  '            <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-inherit__D7XqR link_link__IZzHN link_notUnderlined__szqki styles_categoryLink__9HVh5" href="/categories/energy_supplier" target="_self">',
#  '             <span>',
#  '              Energieversorger',
#  '             </span>',
#  '             <p class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l">',
#  '              38',
#  '             </p>',
#  '            </a>',
#  '           </li>',
#  '           <li class="styles_category__bGrxO">',
#  '            <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-inherit__D7XqR link_link__IZzHN link_notUnderlined__szqki styles_categoryLink__9HVh5" href="/categories/solar_photovoltaic_power_plant" target="_self">',
#  '             <span>',
#  '              Fotovoltaikanlage',
#  '             </span>',
#  '             <p class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l">',
#  '              19',
#  '             </p>',
#  '            </a>',
#  '           </li>',
#  '           <li class="styles_category__bGrxO">',
#  '            <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-inherit__D7XqR link_link__IZzHN link_notUnderlined__szqki styles_categoryLink__9HVh5" href="/categories/gas_company" target="_self">',
#  '             <span>',
#  '              Gasversorgungsunternehmen',
#  '             </span>',
#  '             <p class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l">',
#  '              26',
#  '             </p>',
#  '            </a>',
#  '           </li>',
#  '           <li class="styles_category__bGrxO">',
#  '            <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-inherit__D7XqR link_link__IZzHN link_notUnderlined__szqki styles_categoryLink__9HVh5" href="/categories/coal_supplier" target="_self">',
#  '             <span>',
#  '              Kohlelieferant',
#  '             </span>',
#  '             <p class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l">',
#  '              1',
#  '             </p>',
#  '            </a>',
#  '           </li>',
#  '           <li class="styles_category__bGrxO">',
#  '            <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-inherit__D7XqR link_link__IZzHN link_notUnderlined__szqki styles_categoryLink__9HVh5" href="/categories/green_energy_supplier" target="_self">',
#  '             <span>',
#  '              Ökostromanbieter',
#  '             </span>',
#  '             <p class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l">',
#  '              30',
#  '             </p>',
#  '            </a>',
#  '           </li>',
#  '           <li class="styles_category__bGrxO">',
#  '            <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-inherit__D7XqR link_link__IZzHN link_notUnderlined__szqki styles_categoryLink__9HVh5" href="/categories/solar_energy_company" target="_self">',
#  '             <span>',
#  '              Solarenergieunternehmen',
#  '             </span>',
#  '             <p class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l">',
#  '              85',
#  '             </p>',
#  '            </a>',
#  '           </li>',
#  '           <li class="styles_category__bGrxO">',
#  '            <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-inherit__D7XqR link_link__IZzHN link_notUnderlined__szqki styles_categoryLink__9HVh5" href="/categories/thermal_energy_company" target="_self">',
#  '             <span>',
#  '              Wärmeenergie-Unternehmen',
#  '             </span>',
#  '             <p class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l">',
#  '              6',
#  '             </p>',
#  '            </a>',
#  '           </li>',
#  '          </ul>',
#  '         </div>',
#  '        </aside>',
#  '        <div class="styles_main__XgQiu">',
#  '         <section class="styles_feed__MNr87">',
#  '          <div class="styles_sticky__Y62Bi styles_mobileFilters__9QxpW">',
#  '           <div class="button-toggle_container__DwCGx">',
#  '            <button class="styles_filterButton__9btTA styles_button__796zQ button-toggle_large__92Ne6" data-mobile-filters-filter-button="true" name="open-filters">',
#  '             <span class="typography_heading-xxs__QKBS8 typography_appearance-inherit__D7XqR">',
#  '              Filtern',
#  '             </span>',
#  '             <svg class="icon_icon__ECGRl icon_appearance-inherit__EpnEx" fill="inherit" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">',
#  '              <g clip-path="url(#a)" clip-rule="evenodd" fill-rule="evenodd">',
#  '               <path d="M6 13a3 3 0 1 1-3.5-2.959V0h1v10.041A3 3 0 0 1 6 13Zm-1 0a2 2 0 1 1-4 0 2 2 0 0 1 4 0ZM12.5 5.959V16h1V5.959a3 3 0 1 0-1 0ZM13.002 5h-.004a2 2 0 1 1 .004 0Z">',
#  '               </path>',
#  '              </g>',
#  '              <defs>',
#  '               <clippath id="a">',
#  '                <path d="M0 0h16v16H0z" transform="rotate(-180 8 8)">',
#  '                </path>',
#  '               </clippath>',
#  '              </defs>',
#  '             </svg>',
#  '            </button>',
#  '            <button class="styles_button__796zQ button-toggle_large__92Ne6" data-mobile-filters-sort-button="true" name="open-sort">',
#  '             <span class="typography_heading-xxs__QKBS8 typography_appearance-inherit__D7XqR">',
#  '              Sortieren',
#  '             </span>',
#  '             <svg class="icon_icon__ECGRl icon_appearance-inherit__EpnEx" fill="inherit" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">',
#  '              <path clip-rule="evenodd" d="M11 7H5l3-4 3 4Zm0 2-3 4-3-4h6Z" fill-rule="evenodd">',
#  '              </path>',
#  '             </svg>',
#  '            </button>',
#  '           </div>',
#  '          </div>',
#  '          <div class="styles_feedHeading__ju0kk">',
#  '           <p class="typography_body-m__xgxZ_ typography_appearance-default__AAY17" data-results-count-typography="true">',
#  '            1',
#  '            <!-- -->',
#  '            –',
#  '            <!-- -->',
#  '            20',
#  '            <!-- -->',
#  '            von',
#  '            <!-- -->',
#  '            37',
#  '            <!-- -->',
#  '            Ergebnissen',
#  '           </p>',
#  '           <div class="styles_container__xxHTe styles_desktop__A2Tz2">',
#  '            <label class="typography_body-m__xgxZ_ typography_appearance-default__AAY17 styles_label__ZfXG1" for="category-sort-options-desktop">',
#  '             Sortieren',
#  '            </label>',
#  '            <div class="styles_wrapper__OjsW0">',
#  '             <select class="styles_select__V5fiP styles_select--l___xC_g" data-category-sort-options-select="true" id="category-sort-options-desktop">',
#  '              <option selected="" value="recommended">',
#  '               Am relevantesten',
#  '              </option>',
#  '              <option value="reviews_count">',
#  '               Mit den meisten Bewertungen',
#  '              </option>',
#  '              <option value="latest_review">',
#  '               Mit den neuesten Bewertungen',
#  '              </option>',
#  '             </select>',
#  '             <svg class="icon_icon__ECGRl icon_appearance-default___4uy_" height="16px" viewbox="0 0 20 20" width="16px" xmlns="http://www.w3.org/2000/svg">',
#  '              <path d="m0 5 10 10L20 5z" fill-rule="evenodd">',
#  '              </path>',
#  '             </svg>',
#  '            </div>',
#  '           </div>',
#  '          </div>',
#  '          <div class="section-theme-provider_theme-default__zZfHS" data-constellation-section-theme="default">',
#  '           <div class="paper_paper__1PY90 banner-alert_wrapper__seZv_ banner-alert_info__eFa7V" data-recommended-paper="true">',
#  '            <div class="banner-alert_icon__ckXn6 banner-alert_header__wpXgY">',
#  '             <svg class="icon_icon__ECGRl icon_appearance-default___4uy_" height="18px" viewbox="0 0 16 16" width="18px" xmlns="http://www.w3.org/2000/svg">',
#  '              <path clip-rule="evenodd" d="M8 1a7 7 0 1 0 0 14A7 7 0 0 0 8 1ZM0 8a8 8 0 1 1 16 0A8 8 0 0 1 0 8Z" fill-rule="evenodd">',
#  '              </path>',
#  '              <path clip-rule="evenodd" d="M7.5 7h-.75V6H8.5v5.502h.75v1h-2.5v-1h.75V7ZM6.75 4a1 1 0 1 1 2 0 1 1 0 0 1-2 0Z" fill-rule="evenodd">',
#  '              </path>',
#  '             </svg>',
#  '            </div>',
#  '            <div class="banner-alert_content__MsJB_">',
#  '             <div aria-controls=":R1plnf6:" aria-expanded="false" role="button" tabindex="0">',
#  '              <p class="typography_heading-xxs__QKBS8 typography_appearance-default__AAY17 banner-alert_expandable-title__RpT5M">',
#  '               Was bedeutet die Sortierung nach der Relevanz?',
#  '               <span class="typography_body-m__xgxZ_ typography_appearance-default__AAY17 banner-alert_read-more-link__Rf1Hg">',
#  '                Mehr anzeigen',
#  '               </span>',
#  '              </p>',
#  '             </div>',
#  '             <div aria-hidden="false" class="rah-static rah-static--height-zero" id=":R1plnf6:" style="height:0;overflow:hidden">',
#  '              <div>',
#  '               <div class="banner-alert_expandable-content__dBKbC">',
#  '                <span class="typography_body-m__xgxZ_ typography_appearance-default__AAY17">',
#  '                 <p class="typography_body-m__xgxZ_ typography_appearance-default__AAY17">',
#  '                  Die Sortierung nach der Relevanz listet alle Unternehmen auf, die in einer Kategorie am besten abschneiden, sortiert nach ihrem TrustScore und der Anzahl ihrer Bewertungen. Damit Unternehmen gelistet werden können, müssen sie aktiv zur Bewertungsabgabe einladen und in den letzten 12\xa0Monaten mindestens 25\xa0Bewertungen erhalten haben.',
#  '                 </p>',
#  '                </span>',
#  '               </div>',
#  '              </div>',
#  '             </div>',
#  '            </div>',
#  '           </div>',
#  '          </div>',
#  '          <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_wrapper__2JOo2">',
#  '           <a class="link_internal__7XN06 link_wrapper__5ZJEx styles_linkWrapper__UWs5j" data-business-unit-card-link="true" href="/review/octopusenergy.de" name="business-unit-card" target="_self">',
#  '            <div class="styles_badge__Tkzsi">',
#  '             Am relevantesten',
#  '            </div>',
#  '            <div class="styles_content__98tWf">',
#  '             <div class="styles_logoBox__SF4DX">',
#  '              <picture class="business-profile-image_containmentWrapper__wu_Tp">',
#  '               <source srcset="https://consumersiteimages.trustpilot.net/business-units/5fad2ec87bde450001afb1c4-198x149-1x.avif, https://consumersiteimages.trustpilot.net/business-units/5fad2ec87bde450001afb1c4-198x149-2x.avif 2x" type="image/avif"/>',
#  '               <source srcset="https://consumersiteimages.trustpilot.net/business-units/5fad2ec87bde450001afb1c4-198x149-1x.jpg, https://consumersiteimages.trustpilot.net/business-units/5fad2ec87bde450001afb1c4-198x149-2x.jpg 2x" type="image/jpeg"/>',
#  '               <img alt="" class="business-profile-image_image__jCBDc" src="https://consumersiteimages.trustpilot.net/business-units/5fad2ec87bde450001afb1c4-198x149-1x.jpg"/>',
#  '              </picture>',
#  '             </div>',
#  '             <div class="styles_businessUnitMain__PuwB7">',
#  '              <p class="typography_heading-xs__jSwUz typography_appearance-default__AAY17 styles_displayName__GOhL2">',
#  '               Octopus Energy Germany',
#  '              </p>',
#  '              <div class="styles_rating__pY5Pk">',
#  '               <div class="star-rating_starRating__4rrcf star-rating_responsive__C9oka">',
#  '                <img alt="TrustScore 5 von 5" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-5.svg"/>',
#  '               </div>',
#  '               <p class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_ratingText__yQ5S7">',
#  '                <span class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_trustScore__8emxJ">',
#  '                 <span class="styles_desktop__U5iWw">',
#  '                  TrustScore',
#  '                 </span>',
#  '                 <!-- -->',
#  '                 4,8',
#  '                </span>',
#  '                <span class="styles_separator__TG_uV">',
#  '                 |',
#  '                </span>',
#  '                8.392',
#  '                <!-- -->',
#  '                Bewertungen',
#  '               </p>',
#  '              </div>',
#  '              <div class="styles_metadataRow__pgwwW">',
#  '               <span class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_metadataItem__Qn_Q2 styles_location__ILZb0" data-business-location-typography="true">',
#  '                München',
#  '                <!-- -->',
#  '                ,',
#  '                <!-- -->',
#  '                Deutschland',
#  '               </span>',
#  '              </div>',
#  '             </div>',
#  '            </div>',
#  '           </a>',
#  '           <div class="card_cardContent__sFUOe styles_categoriesLabelsWrapper__AsHrM styles_mobile__wIl_O">',
#  '            <div class="styles_wrapper___E6__ styles_categoriesLabels__FiWQ4">',
#  '             <span class="typography_body-s__aY15Q typography_appearance-default__AAY17">',
#  '              Stromversorgungsunternehmen',
#  '             </span>',
#  '             <span class="styles_categoriesBullet__pPs7C">',
#  '              ·',
#  '             </span>',
#  '             <span class="typography_body-s__aY15Q typography_appearance-default__AAY17">',
#  '              Energieversorger',
#  '             </span>',
#  '             <span class="styles_categoriesBullet__pPs7C">',
#  '              ·',
#  '             </span>',
#  '             <span class="typography_body-s__aY15Q typography_appearance-default__AAY17">',
#  '              Energieanbieter',
#  '             </span>',
#  '             <span class="styles_categoriesBullet__pPs7C">',
#  '              ·',
#  '             </span>',
#  '             <span class="typography_body-s__aY15Q typography_appearance-default__AAY17">',
#  '              Gasversorgungsunternehmen',
#  '             </span>',
#  '             <span class="styles_categoriesBullet__pPs7C">',
#  '              ·',
#  '             </span>',
#  '             <span class="typography_body-s__aY15Q typography_appearance-default__AAY17">',
#  '              Ökostromanbieter',
#  '             </span>',
#  '            </div>',
#  '           </div>',
#  '           <hr class="divider_divider__M85e9 divider_appearance-subtle__DkHcP"/>',
#  '           <div class="card_cardContent__sFUOe styles_footerWrapper__HMFrh">',
#  '            <div class="styles_footer__DoJVj">',
#  '             <span>',
#  '              <button aria-label="Kontakt" class="styles_iconWrapper__Iy_ZV">',
#  '               <svg class="icon_icon__ECGRl" fill="currentColor" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">',
#  '                <path clip-rule="evenodd" d="M10.694 1.537c.217.281.415.592.593.923.321.6.59 1.287.793 2.04h1.983a7.027 7.027 0 0 0-3.37-2.963ZM14.54 5.5h-2.235c.143.789.22 1.63.22 2.5 0 .87-.077 1.711-.22 2.5h2.235c.297-.776.46-1.62.46-2.5 0-.88-.163-1.724-.46-2.5Zm-.476 6H12.08a9.655 9.655 0 0 1-.793 2.04 6.698 6.698 0 0 1-.593.923 7.027 7.027 0 0 0 3.37-2.963Zm-8.758 2.963a6.708 6.708 0 0 1-.593-.923 9.654 9.654 0 0 1-.792-2.04H1.936a7.027 7.027 0 0 0 3.37 2.963ZM1.46 10.5h2.236c-.144-.789-.22-1.63-.22-2.5 0-.87.076-1.711.22-2.5H1.46A6.984 6.984 0 0 0 1 8c0 .88.163 1.724.46 2.5Zm.476-6h1.985c.203-.753.47-1.44.792-2.04.178-.331.376-.642.593-.923A7.027 7.027 0 0 0 1.936 4.5ZM8 0a8 8 0 1 0 0 16A8 8 0 0 0 8 0M5.595 2.933c-.247.46-.461.987-.635 1.567H7.5V1.075c-.677.204-1.35.822-1.905 1.858Zm4.81 0c.247.46.462.987.635 1.567H8.5V1.075c.677.204 1.35.822 1.906 1.858ZM8.5 5.5h2.787c.153.774.238 1.616.238 2.5 0 .884-.085 1.726-.238 2.5H8.5v-5Zm0 6h2.54a8.428 8.428 0 0 1-.634 1.567c-.557 1.036-1.229 1.654-1.906 1.858V11.5Zm-1 0v3.425c-.677-.204-1.35-.822-1.905-1.858A8.426 8.426 0 0 1 4.96 11.5H7.5Zm0-1H4.713A12.91 12.91 0 0 1 4.475 8c0-.884.085-1.726.238-2.5H7.5v5Z" fill-rule="evenodd">',
#  '                </path>',
#  '               </svg>',
#  '               <svg class="icon_icon__ECGRl" fill="currentColor" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">',
#  '                <path clip-rule="evenodd" d="M0 2.5h16v11H0v-11Zm1.789 1L8 9.173 14.211 3.5H1.79ZM15 4.134l-7 6.393-7-6.393V12.5h14V4.134Z" fill-rule="evenodd">',
#  '                </path>',
#  '               </svg>',
#  '               <svg class="icon_icon__ECGRl" fill="currentColor" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">',
#  '                <g clip-path="url(#a)">',
#  '                 <path clip-rule="evenodd" d="m4.622.933.04.057.003.006L6.37 3.604l.002.003a1.7 1.7 0 0 1-.442 2.29l-.036.029c-.392.325-.627.519-.652.85-.026.364.206 1.09 1.562 2.445 1.356 1.357 2.073 1.58 2.426 1.55.318-.027.503-.252.816-.632l.057-.069a1.7 1.7 0 0 1 2.29-.442l.003.002 2.608 1.705.006.004c.204.141.454.37.649.645.188.267.376.655.31 1.09-.031.213-.147.495-.305.774a4.534 4.534 0 0 1-.715.941C14.323 15.422 13.377 16 12.1 16c-1.236 0-2.569-.483-3.877-1.246-1.315-.768-2.642-1.84-3.877-3.075C3.112 10.444 2.033 9.118 1.26 7.8.49 6.49 0 5.15 0 3.9c0-1.274.52-2.215 1.144-2.845C1.751.442 2.478.098 2.954.03c.507-.072.896.088 1.182.327.224.187.387.43.486.576Zm-1.127.191a.46.46 0 0 0-.4-.104c-.223.032-.758.25-1.24.738C1.393 2.227 1 2.924 1 3.9c0 1.001.398 2.161 1.122 3.394.72 1.226 1.74 2.486 2.932 3.678 1.19 1.19 2.45 2.204 3.673 2.918 1.23.718 2.384 1.11 3.373 1.11.949 0 1.652-.422 2.138-.914.245-.247.43-.508.556-.73.134-.237.181-.393.186-.43.01-.065-.014-.19-.139-.366a1.737 1.737 0 0 0-.396-.396l-2.59-1.693a.7.7 0 0 0-.946.19l-.011.017-.013.016-.08.098c-.261.33-.723.91-1.491.975-.841.07-1.85-.47-3.218-1.838-1.369-1.37-1.912-2.381-1.85-3.225.056-.783.638-1.25.97-1.517l.09-.072.016-.013.016-.011a.7.7 0 0 0 .191-.946l-1.694-2.59-.051-.076c-.104-.152-.182-.265-.29-.355Z" fill-rule="evenodd">',
#  '                 </path>',
#  '                </g>',
#  '                <defs>',
#  '                 <clippath id="a">',
#  '                  <path d="M0 0h16v16H0z">',
#  '                  </path>',
#  '                 </clippath>',
#  '                </defs>',
#  '               </svg>',
#  '              </button>',
#  '             </span>',
#  '             <div class="styles_wrapper___E6__ styles_categoriesLabels__FiWQ4 styles_desktop__U5iWw">',
#  '              <span class="typography_body-s__aY15Q typography_appearance-default__AAY17">',
#  '               Stromversorgungsunternehmen',
#  '              </span>',
#  '              <span class="styles_categoriesBullet__pPs7C">',
#  '               ·',
#  '              </span>',
#  '              <span class="typography_body-s__aY15Q typography_appearance-default__AAY17">',
#  '               Energieversorger',
#  '              </span>',
#  '              <span class="styles_categoriesBullet__pPs7C">',
#  '               ·',
#  '              </span>',
#  '              <span class="typography_body-s__aY15Q typography_appearance-default__AAY17">',
#  '               Energieanbieter',
#  '              </span>',
#  '              <span class="styles_categoriesBullet__pPs7C">',
#  '               ·',
#  '              </span>',
#  '              <span class="typography_body-s__aY15Q typography_appearance-default__AAY17">',
#  '               Gasversorgungsunternehmen',
#  '              </span>',
#  '              <span class="styles_categoriesBullet__pPs7C">',
#  '               ·',
#  '              </span>',
#  '              <span class="typography_body-s__aY15Q typography_appearance-default__AAY17">',
#  '               Ökostromanbieter',
#  '              </span>',
#  '             </div>',
#  '             <button aria-controls="latest-reviews-5fad2ec87bde450001afb1c4-panel" aria-expanded="false" class="styles_reviewsButton__pWKds" data-recent-reviews-toggle-button="true">',
#  '              Neueste Bewertungen',
#  '              <!-- -->',
#  '              <svg class="icon_icon__ECGRl" fill="currentColor" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">',
#  '               <path clip-rule="evenodd" d="m8.003 10.289 5.617-6.557.76.65-6.377 7.444L1.62 4.383l.76-.651 5.623 6.557Z" fill-rule="evenodd">',
#  '               </path>',
#  '              </svg>',
#  '             </button>',
#  '            </div>',
#  '           </div>',
#  '           <div aria-hidden="true" class="styles_latestReviews__1RLpK styles_hide__Urk8b" id="latest-reviews-5fad2ec87bde450001afb1c4-panel">',
#  '            <div class="styles_carouselWrapper__exiEz styles_carouselWrapper__HepHU">',
#  '             <div class="styles_carousel__0ug7V styles_stickyScroll__awIPl styles_carousel__OumfX">',
#  '              <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">',
#  '               <div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">',
#  '                </div>',
#  '                <div class="styles_reviewRow__ho_WO">',
#  '                 <div class="styles_skeleton___6L7B styles_round__XWrvZ">',
#  '                 </div>',
#  '                 <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">',
#  '                  <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>',
#  '                 </div>',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '               </div>',
#  '              </div>',
#  '              <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">',
#  '               <div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">',
#  '                </div>',
#  '                <div class="styles_reviewRow__ho_WO">',
#  '                 <div class="styles_skeleton___6L7B styles_round__XWrvZ">',
#  '                 </div>',
#  '                 <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">',
#  '                  <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>',
#  '                 </div>',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '               </div>',
#  '              </div>',
#  '              <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">',
#  '               <div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">',
#  '                </div>',
#  '                <div class="styles_reviewRow__ho_WO">',
#  '                 <div class="styles_skeleton___6L7B styles_round__XWrvZ">',
#  '                 </div>',
#  '                 <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">',
#  '                  <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>',
#  '                 </div>',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '               </div>',
#  '              </div>',
#  '              <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">',
#  '               <div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">',
#  '                </div>',
#  '                <div class="styles_reviewRow__ho_WO">',
#  '                 <div class="styles_skeleton___6L7B styles_round__XWrvZ">',
#  '                 </div>',
#  '                 <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">',
#  '                  <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>',
#  '                 </div>',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '               </div>',
#  '              </div>',
#  '              <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">',
#  '               <div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">',
#  '                </div>',
#  '                <div class="styles_reviewRow__ho_WO">',
#  '                 <div class="styles_skeleton___6L7B styles_round__XWrvZ">',
#  '                 </div>',
#  '                 <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">',
#  '                  <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>',
#  '                 </div>',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '               </div>',
#  '              </div>',
#  '              <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">',
#  '               <div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">',
#  '                </div>',
#  '                <div class="styles_reviewRow__ho_WO">',
#  '                 <div class="styles_skeleton___6L7B styles_round__XWrvZ">',
#  '                 </div>',
#  '                 <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">',
#  '                  <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>',
#  '                 </div>',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '               </div>',
#  '              </div>',
#  '              <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">',
#  '               <div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">',
#  '                </div>',
#  '                <div class="styles_reviewRow__ho_WO">',
#  '                 <div class="styles_skeleton___6L7B styles_round__XWrvZ">',
#  '                 </div>',
#  '                 <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">',
#  '                  <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>',
#  '                 </div>',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '               </div>',
#  '              </div>',
#  '              <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">',
#  '               <div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">',
#  '                </div>',
#  '                <div class="styles_reviewRow__ho_WO">',
#  '                 <div class="styles_skeleton___6L7B styles_round__XWrvZ">',
#  '                 </div>',
#  '                 <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">',
#  '                  <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>',
#  '                 </div>',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '               </div>',
#  '              </div>',
#  '              <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">',
#  '               <div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">',
#  '                </div>',
#  '                <div class="styles_reviewRow__ho_WO">',
#  '                 <div class="styles_skeleton___6L7B styles_round__XWrvZ">',
#  '                 </div>',
#  '                 <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">',
#  '                  <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>',
#  '                 </div>',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '               </div>',
#  '              </div>',
#  '              <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">',
#  '               <div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">',
#  '                </div>',
#  '                <div class="styles_reviewRow__ho_WO">',
#  '                 <div class="styles_skeleton___6L7B styles_round__XWrvZ">',
#  '                 </div>',
#  '                 <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">',
#  '                  <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>',
#  '                 </div>',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '               </div>',
#  '              </div>',
#  '             </div>',
#  '            </div>',
#  '           </div>',
#  '          </div>',
#  '          <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_wrapper__2JOo2">',
#  '           <a class="link_internal__7XN06 link_wrapper__5ZJEx styles_linkWrapper__UWs5j" data-business-unit-card-link="true" href="/review/ostrom.de" name="business-unit-card" target="_self">',
#  '            <div class="styles_badge__Tkzsi">',
#  '             Am relevantesten',
#  '            </div>',
#  '            <div class="styles_content__98tWf">',
#  '             <div class="styles_logoBox__SF4DX">',
#  '              <picture class="business-profile-image_containmentWrapper__wu_Tp">',
#  '               <source srcset="https://consumersiteimages.trustpilot.net/business-units/607f2b7694941100013939e4-198x149-1x.avif, https://consumersiteimages.trustpilot.net/business-units/607f2b7694941100013939e4-198x149-2x.avif 2x" type="image/avif"/>',
#  '               <source srcset="https://consumersiteimages.trustpilot.net/business-units/607f2b7694941100013939e4-198x149-1x.jpg, https://consumersiteimages.trustpilot.net/business-units/607f2b7694941100013939e4-198x149-2x.jpg 2x" type="image/jpeg"/>',
#  '               <img alt="" class="business-profile-image_image__jCBDc" src="https://consumersiteimages.trustpilot.net/business-units/607f2b7694941100013939e4-198x149-1x.jpg"/>',
#  '              </picture>',
#  '             </div>',
#  '             <div class="styles_businessUnitMain__PuwB7">',
#  '              <p class="typography_heading-xs__jSwUz typography_appearance-default__AAY17 styles_displayName__GOhL2">',
#  '               Ostrom',
#  '              </p>',
#  '              <div class="styles_rating__pY5Pk">',
#  '               <div class="star-rating_starRating__4rrcf star-rating_responsive__C9oka">',
#  '                <img alt="TrustScore 5 von 5" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-5.svg"/>',
#  '               </div>',
#  '               <p class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_ratingText__yQ5S7">',
#  '                <span class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_trustScore__8emxJ">',
#  '                 <span class="styles_desktop__U5iWw">',
#  '                  TrustScore',
#  '                 </span>',
#  '                 <!-- -->',
#  '                 4,8',
#  '                </span>',
#  '                <span class="styles_separator__TG_uV">',
#  '                 |',
#  '                </span>',
#  '                1.607',
#  '                <!-- -->',
#  '                Bewertungen',
#  '               </p>',
#  '              </div>',
#  '              <div class="styles_metadataRow__pgwwW">',
#  '               <span class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_metadataItem__Qn_Q2 styles_location__ILZb0" data-business-location-typography="true">',
#  '                Berlin',
#  '                <!-- -->',
#  '                ,',
#  '                <!-- -->',
#  '                Deutschland',
#  '               </span>',
#  '              </div>',
#  '             </div>',
#  '            </div>',
#  '           </a>',
#  '           <div class="card_cardContent__sFUOe styles_categoriesLabelsWrapper__AsHrM styles_mobile__wIl_O">',
#  '            <div class="styles_wrapper___E6__ styles_categoriesLabels__FiWQ4">',
#  '             <span class="typography_body-s__aY15Q typography_appearance-default__AAY17">',
#  '              Ökostromanbieter',
#  '             </span>',
#  '             <span class="styles_categoriesBullet__pPs7C">',
#  '              ·',
#  '             </span>',
#  '             <span class="typography_body-s__aY15Q typography_appearance-default__AAY17">',
#  '              Stromversorgungsunternehmen',
#  '             </span>',
#  '             <span class="styles_categoriesBullet__pPs7C">',
#  '              ·',
#  '             </span>',
#  '             <span class="typography_body-s__aY15Q typography_appearance-default__AAY17">',
#  '              Energieanbieter',
#  '             </span>',
#  '             <span class="styles_categoriesBullet__pPs7C">',
#  '              ·',
#  '             </span>',
#  '             <span class="typography_body-s__aY15Q typography_appearance-default__AAY17">',
#  '              Solarenergieunternehmen',
#  '             </span>',
#  '             <span class="styles_categoriesBullet__pPs7C">',
#  '              ·',
#  '             </span>',
#  '             <span class="typography_body-s__aY15Q typography_appearance-default__AAY17">',
#  '              Energieversorger',
#  '             </span>',
#  '            </div>',
#  '           </div>',
#  '           <hr class="divider_divider__M85e9 divider_appearance-subtle__DkHcP"/>',
#  '           <div class="card_cardContent__sFUOe styles_footerWrapper__HMFrh">',
#  '            <div class="styles_footer__DoJVj">',
#  '             <span>',
#  '              <button aria-label="Kontakt" class="styles_iconWrapper__Iy_ZV">',
#  '               <svg class="icon_icon__ECGRl" fill="currentColor" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">',
#  '                <path clip-rule="evenodd" d="M10.694 1.537c.217.281.415.592.593.923.321.6.59 1.287.793 2.04h1.983a7.027 7.027 0 0 0-3.37-2.963ZM14.54 5.5h-2.235c.143.789.22 1.63.22 2.5 0 .87-.077 1.711-.22 2.5h2.235c.297-.776.46-1.62.46-2.5 0-.88-.163-1.724-.46-2.5Zm-.476 6H12.08a9.655 9.655 0 0 1-.793 2.04 6.698 6.698 0 0 1-.593.923 7.027 7.027 0 0 0 3.37-2.963Zm-8.758 2.963a6.708 6.708 0 0 1-.593-.923 9.654 9.654 0 0 1-.792-2.04H1.936a7.027 7.027 0 0 0 3.37 2.963ZM1.46 10.5h2.236c-.144-.789-.22-1.63-.22-2.5 0-.87.076-1.711.22-2.5H1.46A6.984 6.984 0 0 0 1 8c0 .88.163 1.724.46 2.5Zm.476-6h1.985c.203-.753.47-1.44.792-2.04.178-.331.376-.642.593-.923A7.027 7.027 0 0 0 1.936 4.5ZM8 0a8 8 0 1 0 0 16A8 8 0 0 0 8 0M5.595 2.933c-.247.46-.461.987-.635 1.567H7.5V1.075c-.677.204-1.35.822-1.905 1.858Zm4.81 0c.247.46.462.987.635 1.567H8.5V1.075c.677.204 1.35.822 1.906 1.858ZM8.5 5.5h2.787c.153.774.238 1.616.238 2.5 0 .884-.085 1.726-.238 2.5H8.5v-5Zm0 6h2.54a8.428 8.428 0 0 1-.634 1.567c-.557 1.036-1.229 1.654-1.906 1.858V11.5Zm-1 0v3.425c-.677-.204-1.35-.822-1.905-1.858A8.426 8.426 0 0 1 4.96 11.5H7.5Zm0-1H4.713A12.91 12.91 0 0 1 4.475 8c0-.884.085-1.726.238-2.5H7.5v5Z" fill-rule="evenodd">',
#  '                </path>',
#  '               </svg>',
#  '               <svg class="icon_icon__ECGRl" fill="currentColor" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">',
#  '                <path clip-rule="evenodd" d="M0 2.5h16v11H0v-11Zm1.789 1L8 9.173 14.211 3.5H1.79ZM15 4.134l-7 6.393-7-6.393V12.5h14V4.134Z" fill-rule="evenodd">',
#  '                </path>',
#  '               </svg>',
#  '              </button>',
#  '             </span>',
#  '             <div class="styles_wrapper___E6__ styles_categoriesLabels__FiWQ4 styles_desktop__U5iWw">',
#  '              <span class="typography_body-s__aY15Q typography_appearance-default__AAY17">',
#  '               Ökostromanbieter',
#  '              </span>',
#  '              <span class="styles_categoriesBullet__pPs7C">',
#  '               ·',
#  '              </span>',
#  '              <span class="typography_body-s__aY15Q typography_appearance-default__AAY17">',
#  '               Stromversorgungsunternehmen',
#  '              </span>',
#  '              <span class="styles_categoriesBullet__pPs7C">',
#  '               ·',
#  '              </span>',
#  '              <span class="typography_body-s__aY15Q typography_appearance-default__AAY17">',
#  '               Energieanbieter',
#  '              </span>',
#  '              <span class="styles_categoriesBullet__pPs7C">',
#  '               ·',
#  '              </span>',
#  '              <span class="typography_body-s__aY15Q typography_appearance-default__AAY17">',
#  '               Solarenergieunternehmen',
#  '              </span>',
#  '              <span class="styles_categoriesBullet__pPs7C">',
#  '               ·',
#  '              </span>',
#  '              <span class="typography_body-s__aY15Q typography_appearance-default__AAY17">',
#  '               Energieversorger',
#  '              </span>',
#  '             </div>',
#  '             <button aria-controls="latest-reviews-607f2b7694941100013939e4-panel" aria-expanded="false" class="styles_reviewsButton__pWKds" data-recent-reviews-toggle-button="true">',
#  '              Neueste Bewertungen',
#  '              <!-- -->',
#  '              <svg class="icon_icon__ECGRl" fill="currentColor" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">',
#  '               <path clip-rule="evenodd" d="m8.003 10.289 5.617-6.557.76.65-6.377 7.444L1.62 4.383l.76-.651 5.623 6.557Z" fill-rule="evenodd">',
#  '               </path>',
#  '              </svg>',
#  '             </button>',
#  '            </div>',
#  '           </div>',
#  '           <div aria-hidden="true" class="styles_latestReviews__1RLpK styles_hide__Urk8b" id="latest-reviews-607f2b7694941100013939e4-panel">',
#  '            <div class="styles_carouselWrapper__exiEz styles_carouselWrapper__HepHU">',
#  '             <div class="styles_carousel__0ug7V styles_stickyScroll__awIPl styles_carousel__OumfX">',
#  '              <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">',
#  '               <div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">',
#  '                </div>',
#  '                <div class="styles_reviewRow__ho_WO">',
#  '                 <div class="styles_skeleton___6L7B styles_round__XWrvZ">',
#  '                 </div>',
#  '                 <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">',
#  '                  <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>',
#  '                 </div>',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '               </div>',
#  '              </div>',
#  '              <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">',
#  '               <div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">',
#  '                </div>',
#  '                <div class="styles_reviewRow__ho_WO">',
#  '                 <div class="styles_skeleton___6L7B styles_round__XWrvZ">',
#  '                 </div>',
#  '                 <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">',
#  '                  <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>',
#  '                 </div>',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '               </div>',
#  '              </div>',
#  '              <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">',
#  '               <div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">',
#  '                </div>',
#  '                <div class="styles_reviewRow__ho_WO">',
#  '                 <div class="styles_skeleton___6L7B styles_round__XWrvZ">',
#  '                 </div>',
#  '                 <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">',
#  '                  <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>',
#  '                 </div>',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '               </div>',
#  '              </div>',
#  '              <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">',
#  '               <div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">',
#  '                </div>',
#  '                <div class="styles_reviewRow__ho_WO">',
#  '                 <div class="styles_skeleton___6L7B styles_round__XWrvZ">',
#  '                 </div>',
#  '                 <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">',
#  '                  <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>',
#  '                 </div>',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">',
#  '                </div>',
#  '               </div>',
#  '              </div>',
#  '              <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">',
#  '               <div>',
#  '                <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">',
#  '                </div>',
#  '                <div class="styles_reviewRow__ho_WO">',
#  '                 <div class="styles_skeleton___6L7B styles_round__XWrvZ">',
#  '                 </div>',
#  '                 <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">']

# %% [markdown]
# ### Identify the HTML elements containing the name, score, number of votes and site of each energy distributor.
#
# On the page, the energy suppliers are represented in a similar way, it is therefore logical that the structure of the web code is the same.
#
# The page is not set up as a table but it is a sequence of div containers, with class 'paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_wrapper__2JOo2'.
#
# Important key words are:
#  - p 'typography_heading-xs__jSwUz typography_appearance-default__AAY17 styles_displayName__GOhL2' for the name of the energy supplier
#  - p 'typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_ratingText__yQ5S7' with 'TrustScore' for the rating score of the energy supplier and the respective number of votes; alternate: span 'typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_trustScore__8emxJ' for TrustScore only
#  - span 'typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_metadataItem__Qn_Q2 styles_location__ILZb0' for supplier's business location; alternate: div 'styles_metadataRow__pgwwW'
#  - div 'card_cardContent__sFUOe styles_categoriesLabelsWrapper__AsHrM styles_mobile__wIl_O' for energy supplier categories, explaining if the company also offers gas or eco-power
#  - a class="link_internal__7XN06 link_wrapper__5ZJEx styles_linkWrapper__UWs5j" for hyperlink to comment page

# %% [markdown]
# Using the findAll method, we will retrieve the HTML code containing relevant elements in a variable named ener_imdb.

# %%
#Retrieve relevant HTML code of page 1 --> find_all rows
ener_tp = page1_soup.findAll("div", attrs={'class': 'paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_wrapper__2JOo2'})

# %%
#Retrieve relevant HTML code of page 1 --> find_all rows
ener2_tp = page2_soup.findAll("div", attrs={'class': 'paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_wrapper__2JOo2'})

# %% [markdown]
# In order to achieve and test access to the required information, we will start with the first listed energy supplier on page 1.

# %%
# get the first item from ener_imdb
ener1 = ener_tp[0]

# write content of first energy supplier on page 1 (Octopus Energy Germany)
ener1.text
# Out:
# 'Am relevantestenOctopus Energy GermanyTrustScore 4,8|8.392 BewertungenMünchen,\xa0DeutschlandStromversorgungsunternehmen·Energieversorger·Energieanbieter·Gasversorgungsunternehmen·ÖkostromanbieterStromversorgungsunternehmen·Energieversorger·Energieanbieter·Gasversorgungsunternehmen·ÖkostromanbieterNeueste Bewertungen\xa0'

# %%
# recover the name
name = ener1.find('p', attrs={'class': 'typography_heading-xs__jSwUz typography_appearance-default__AAY17 styles_displayName__GOhL2'}).text
print(name)
# Out:
# Octopus Energy Germany

# %%
# recover the score
score = ener1.find('span', attrs={'class': 'typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_trustScore__8emxJ'}).text
print(score)
# Out:
# TrustScore 4,8

# %%
# recover the score only
score = ener1.find('span', attrs={'class': 'typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_trustScore__8emxJ'}).get_text().strip('TrustScore ')
print(score)
# Out:
# 4,8

# %%
# recover the score and the attributes
score = ener1.find('p', attrs={'class': 'typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_ratingText__yQ5S7'}).text
print(score)
# Out:
# TrustScore 4,8|8.392 Bewertungen

# %%
# strip explanations
score = ener1.find('p', attrs={'class': 'typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_ratingText__yQ5S7'}).get_text().strip(' Bewertungen').strip('TrustScore ')
print(score)
# Out:
# 4,8|8.392

# %%
# get categories
categ = ener1.find('div', attrs={'class': 'card_cardContent__sFUOe styles_categoriesLabelsWrapper__AsHrM styles_mobile__wIl_O'}).get_text()
print(categ)
# Out:
# Stromversorgungsunternehmen·Energieversorger·Energieanbieter·Gasversorgungsunternehmen·Ökostromanbieter

# %%
# recover the location
location = ener1.find('div', attrs={'class': 'styles_metadataRow__pgwwW'}).get_text()
print(location)
# Out:
# München, Deutschland

# %%
# get the hyperlink for customers' comment page
comment = 'https://de.trustpilot.com' + ener1.find('a', attrs={'class': 'link_internal__7XN06 link_wrapper__5ZJEx styles_linkWrapper__UWs5j'})['href']
print(comment)
# Out:
# https://de.trustpilot.com/review/octopusenergy.de

# %% [markdown]
# ### Collect the energy supplier data in a data frame
#
# We can use a for loop to iterate on the ener_tp variable of the first page, containing all the pertinent information on the energy suppliers.
#
# The information will be stored in lists, which can then be transformed in a data frame with the zip function.
#
# These steps can be repeated for the second page as well, stored into the ener2_tp variable.
#
# Finally, both data frames can be concatentated to create one data frame.

# %%
## Page 1
#set variable lists for for-loop
names = []
scores = []
locations = []
categories = []
comments = []

#iterate through table rows with for loop
for supplier in ener_tp:

    #find name and append to list
    try:
        name = supplier.find('p', attrs={'class': 'typography_heading-xs__jSwUz typography_appearance-default__AAY17 styles_displayName__GOhL2'}).text
    except Exception as e: 
        name = "Not Available"
    names.append(name)
    
    #find TrustScore and append to list
    try: 
        score = supplier.find('p', attrs={'class': 'typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_ratingText__yQ5S7'}).get_text().strip(' Bewertungen').strip('TrustScore ')
    except Exception as e: 
        score = "0,0|0"
    scores.append(score)
    
    #find location and append to list
    try:
        location = supplier.find('div', attrs={'class': 'styles_metadataRow__pgwwW'}).get_text()
    except Exception as e:
        location = "Not Available"
    locations.append(location)
    
    #find categories and append to list
    try:
        categ = supplier.find('div', attrs={'class': 'card_cardContent__sFUOe styles_categoriesLabelsWrapper__AsHrM styles_mobile__wIl_O'}).get_text()
    except Exception as e:
        categ = "Not Available"
    categories.append(categ)
    
    #find link to customer comment sit
    try:
        comment = 'https://de.trustpilot.com' + supplier.find('a', attrs={'class': 'link_internal__7XN06 link_wrapper__5ZJEx styles_linkWrapper__UWs5j'})['href']
    except Exception as e:
        comment = "Not Available"
    comments.append(comment)

#check with print
print("Names (first 5 from list): \n", names[0:5])
print("Scores (first 5 from list): \n", scores[0:5])
print("Locations (first 5 from list): \n", locations[0:5])
print("Categories (first 5 from list): \n", categories[0:5])
print("Comments (first 5 from list: \n", comments[0:5])
# Out:
# Names (first 5 from list):
#  ['Octopus Energy Germany', 'Ostrom', 'Rabot Charge', 'MONTANA Group', 'E.ON Energie Deutschland GmbH']
# Scores (first 5 from list):
#  ['4,8|8.392', '4,8|1.607', '4,3|176', '4,0|3.153', '3,7|13.467']
# Locations (first 5 from list):
#  ['München,\xa0Deutschland', 'Berlin,\xa0Deutschland', 'Hamburg,\xa0Deutschland', 'Grünwald,\xa0Deutschland', 'München,\xa0Deutschland']
# Categories (first 5 from list):
#  ['Stromversorgungsunternehmen·Energieversorger·Energieanbieter·Gasversorgungsunternehmen·Ökostromanbieter', 'Ökostromanbieter·Stromversorgungsunternehmen·Energieanbieter·Solarenergieunternehmen·Energieversorger', 'Ökostromanbieter·Energieanbieter·Energieversorger·Stromversorgungsunternehmen', 'Kraftstofflieferant·Energieanbieter·Stromversorgungsunternehmen·Ökostromanbieter·Gasversorgungsunternehmen·Mineralölunternehmen', 'Solartechnikanbieter·Energieanbieter·Stromversorgungsunternehmen·Energieversorger·Gasversorgungsunternehmen·Ökostromanbieter']
# Comments (first 5 from list:
#  ['https://de.trustpilot.com/review/octopusenergy.de', 'https://de.trustpilot.com/review/ostrom.de', 'https://de.trustpilot.com/review/rabot-charge.de', 'https://de.trustpilot.com/review/montana-energie.de', 'https://de.trustpilot.com/review/eon.de']

# %%
#create dataframe with zip function
suppliers = pd.DataFrame(list(zip(names, locations, scores, categories, comments)), columns=["supplier", "location", "score_votes", "cat", "comment"])

#check
suppliers.head()
# Out:
#                         supplier               location score_votes  \
# 0         Octopus Energy Germany   München, Deutschland   4,8|8.392
# 1                         Ostrom    Berlin, Deutschland   4,8|1.607
# 2                   Rabot Charge   Hamburg, Deutschland     4,3|176
# 3                  MONTANA Group  Grünwald, Deutschland   4,0|3.153
# 4  E.ON Energie Deutschland GmbH   München, Deutschland  3,7|13.467
#
#                                                  cat  \
# 0  Stromversorgungsunternehmen·Energieversorger·E...
# 1  Ökostromanbieter·Stromversorgungsunternehmen·E...
# 2  Ökostromanbieter·Energieanbieter·Energieversor...
# 3  Kraftstofflieferant·Energieanbieter·Stromverso...
# 4  Solartechnikanbieter·Energieanbieter·Stromvers...
#
#                                              comment
# 0  https://de.trustpilot.com/review/octopusenergy.de
# 1         https://de.trustpilot.com/review/ostrom.de
# 2   https://de.trustpilot.com/review/rabot-charge.de
# 3  https://de.trustpilot.com/review/montana-energ...
# 4            https://de.trustpilot.com/review/eon.de

# %%
suppliers.info()
# 20 entries is correct, these are displayed on first result page
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   supplier     20 non-null     object
#  1   location     20 non-null     object
#  2   score_votes  20 non-null     object
#  3   cat          20 non-null     object
#  4   comment      20 non-null     object
# dtypes: object(5)
# memory usage: 932.0+ bytes

# %%
## Page 2
#set variable lists for for-loop
names = []
scores = []
locations = []
categories = []
comments = []

#iterate through table rows with for loop
for supplier in ener2_tp:

    #find name and append to list
    try:
        name = supplier.find('p', attrs={'class': 'typography_heading-xs__jSwUz typography_appearance-default__AAY17 styles_displayName__GOhL2'}).text
    except Exception as e: 
        name = "Not Available"
    names.append(name)
    
    #find TrustScore and append to list
    try: 
        score = supplier.find('p', attrs={'class': 'typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_ratingText__yQ5S7'}).get_text().strip(' Bewertungen').strip('TrustScore ')
    except Exception as e: 
        score = "0,0|0"
    scores.append(score)
    
    #find location and append to list
    try:
        location = supplier.find('div', attrs={'class': 'styles_metadataRow__pgwwW'}).get_text()
    except Exception as e:
        location = "Not Available"
    locations.append(location)
    
    #find categories and append to list
    try:
        categ = supplier.find('div', attrs={'class': 'card_cardContent__sFUOe styles_categoriesLabelsWrapper__AsHrM styles_mobile__wIl_O'}).get_text()
    except Exceptions as e:
        categ = "Not Available"
    categories.append(categ)
    
     #find link to customer comment sit
    try:
        comment = 'https://de.trustpilot.com' + supplier.find('a', attrs={'class': 'link_internal__7XN06 link_wrapper__5ZJEx styles_linkWrapper__UWs5j'})['href']
    except Exception as e:
        comment = "Not Available"
    comments.append(comment)

#check with print
print("Names (first 5 from list): \n", names[0:5])
print("Scores (first 5 from list): \n", scores[0:5])
print("Locations (first 5 from list): \n", locations[0:5])
print("Categories (first 5 from list): \n", categories[0:5])
print("Comments (first 5 from list: \n", comments[0:5])
# Out:
# Names (first 5 from list):
#  ['Gas-und-Stromvergleich.de', 'nowenergy', 'CHONO MEDIA', 'Fresh Energy', 'Polarstern Energie']
# Scores (first 5 from list):
#  ['0,0|0', '3,4|81', '3,2|39', '3,1|68', '3,1|32']
# Locations (first 5 from list):
#  ['', 'Berlin,\xa0Deutschland', '', 'Berlin,\xa0Deutschland', 'München,\xa0Deutschland']
# Categories (first 5 from list):
#  ['Stromversorgungsunternehmen·Gasversorgungsunternehmen', 'Gasversorgungsunternehmen·Stromversorgungsunternehmen·Internetanbieter·Energieversorger·Telekommunikationsanbieter·Telefon- und Internetdienst', 'Reiseanbieter·Telekommunikationsanbieter·Stromversorgungsunternehmen·Online-Marktplatz', 'Stromversorgungsunternehmen', 'Energieanbieter·Ökostromanbieter·Stromversorgungsunternehmen·Gasversorgungsunternehmen']
# Comments (first 5 from list:
#  ['https://de.trustpilot.com/review/www.gas-und-stromvergleich.de', 'https://de.trustpilot.com/review/www.nowenergy.de', 'https://de.trustpilot.com/review/www.chono.de', 'https://de.trustpilot.com/review/getfresh.energy', 'https://de.trustpilot.com/review/polarstern-energie.de']

# %%
#create dataframe with zip function
suppliers2 = pd.DataFrame(list(zip(names, locations, scores, categories, comments)), columns=["supplier", "location", "score_votes", "cat", "comment"])

#check
suppliers2.head()
# Out:
#                     supplier              location score_votes  \
# 0  Gas-und-Stromvergleich.de                             0,0|0
# 1                  nowenergy   Berlin, Deutschland      3,4|81
# 2                CHONO MEDIA                            3,2|39
# 3               Fresh Energy   Berlin, Deutschland      3,1|68
# 4         Polarstern Energie  München, Deutschland      3,1|32
#
#                                                  cat  \
# 0  Stromversorgungsunternehmen·Gasversorgungsunte...
# 1  Gasversorgungsunternehmen·Stromversorgungsunte...
# 2  Reiseanbieter·Telekommunikationsanbieter·Strom...
# 3                        Stromversorgungsunternehmen
# 4  Energieanbieter·Ökostromanbieter·Stromversorgu...
#
#                                              comment
# 0  https://de.trustpilot.com/review/www.gas-und-s...
# 1  https://de.trustpilot.com/review/www.nowenergy.de
# 2      https://de.trustpilot.com/review/www.chono.de
# 3   https://de.trustpilot.com/review/getfresh.energy
# 4  https://de.trustpilot.com/review/polarstern-en...

# %%
suppliers2.info()
# 17 entries is correct, these are displayed on second result page
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   supplier     17 non-null     object
#  1   location     17 non-null     object
#  2   score_votes  17 non-null     object
#  3   cat          17 non-null     object
#  4   comment      17 non-null     object
# dtypes: object(5)
# memory usage: 812.0+ bytes

# %%
## Use pandas.concat() method to unify the supplier data frames
ener_suppliers = pd.concat([suppliers, suppliers2], ignore_index=True, sort=False)

# %%
# check
display(ener_suppliers)
# Out:
#                              supplier                           location  \
# 0              Octopus Energy Germany               München, Deutschland
# 1                              Ostrom                Berlin, Deutschland
# 2                        Rabot Charge               Hamburg, Deutschland
# 3                       MONTANA Group              Grünwald, Deutschland
# 4       E.ON Energie Deutschland GmbH               München, Deutschland
# 5                    Grünwelt Energie                Kaarst, Deutschland
# 6                        RheinEnergie                  Köln, Deutschland
# 7                            badenova  Freiburg im Breisgau, Deutschland
# 8                        pricewise.de            Heidelberg, Deutschland
# 9                     DFM-Select GmbH             Metzingen, Deutschland
# 10       Vattenfall Europe Sales GmbH
# 11                Erdgas Südwest GmbH             Ettlingen, Deutschland
# 12                           Zenstrom                Berlin, Deutschland
# 13                         VeganStrom                Berlin, Deutschland
# 14  Fair Trade Power Deutschland GmbH               München, Deutschland
# 15                Lekker Energie GmbH                Berlin, Deutschland
# 16                           1KOMMA5°               Hamburg, Deutschland
# 17                        Paketsparer                Berlin, Deutschland
# 18                        NEW Energie       Mönchengladbach, Deutschland
# 19                   SWK ENERGIE GmbH               Krefeld, Deutschland
# 20          Gas-und-Stromvergleich.de
# 21                          nowenergy                Berlin, Deutschland
# 22                        CHONO MEDIA
# 23                       Fresh Energy                Berlin, Deutschland
# 24                 Polarstern Energie               München, Deutschland
# 25                         Primastrom                Berlin, Deutschland
# 26                        eprimo GmbH          Neu-Isenburg, Deutschland
# 27                         voxenergie                Berlin, Deutschland
# 28                     Lition Energie                Berlin, Deutschland
# 29                          Oekostrom
# 30                          MEP Werke           Eckernförde, Deutschland
# 31                         LichtBlick               Hamburg, Deutschland
# 32                                RWE                 Essen, Deutschland
# 33                                EWE
# 34                      Mein Stromgas               Dorsten, Deutschland
# 35                         OPTUM GmbH
# 36                       Netzberatung                Kassel, Deutschland
#
#    score_votes                                                cat  \
# 0    4,8|8.392  Stromversorgungsunternehmen·Energieversorger·E...
# 1    4,8|1.607  Ökostromanbieter·Stromversorgungsunternehmen·E...
# 2      4,3|176  Ökostromanbieter·Energieanbieter·Energieversor...
# 3    4,0|3.153  Kraftstofflieferant·Energieanbieter·Stromverso...
# 4   3,7|13.467  Solartechnikanbieter·Energieanbieter·Stromvers...
# 5    3,6|1.966                        Stromversorgungsunternehmen
# 6      3,4|547  Stromversorgungsunternehmen·Energieanbieter·Ök...
# 7      2,8|242  Stromversorgungsunternehmen·Ökostromanbieter·G...
# 8      4,8|119  Gasversorgungsunternehmen·Stromversorgungsunte...
# 9       4,6|22  Anbieter von Elektronikbauteilen·Technischer K...
# 10  4,4|10.260  Stromversorgungsunternehmen·Gasversorgungsunte...
# 11      4,4|46  Ökostromanbieter·Gasversorgungsunternehmen·Str...
# 12      4,0|89  Energieanbieter·Ökostromanbieter·Stromversorgu...
# 13      4,0|30  Stromversorgungsunternehmen·Ökostromanbieter·E...
# 14       4,0|3  Stromversorgungsunternehmen·Ökostromanbieter·E...
# 15     3,9|224  Energieanbieter·Gasversorgungsunternehmen·Stro...
# 16      3,8|15  Energieanlagen und -lösungen·Stromversorgungsu...
# 17      3,7|49  Telekommunikationsanbieter·Internetanbieter·Te...
# 18     3,6|618                        Stromversorgungsunternehmen
# 19     3,6|140  Stadtwerke·Ökostromanbieter·Stromversorgungsun...
# 20       0,0|0  Stromversorgungsunternehmen·Gasversorgungsunte...
# 21      3,4|81  Gasversorgungsunternehmen·Stromversorgungsunte...
# 22      3,2|39  Reiseanbieter·Telekommunikationsanbieter·Strom...
# 23      3,1|68                        Stromversorgungsunternehmen
# 24      3,1|32  Energieanbieter·Ökostromanbieter·Stromversorgu...
# 25     2,8|127  Stromversorgungsunternehmen·Telekommunikations...
# 26   2,6|8.863  Stromversorgungsunternehmen·Energieversorger·G...
# 27     2,4|133  Internetanbieter·Stromversorgungsunternehmen·G...
# 28     1,9|125                        Stromversorgungsunternehmen
# 29      1,7|45  Gasversorgungsunternehmen·Stromversorgungsunte...
# 30     1,5|961                        Stromversorgungsunternehmen
# 31   1,3|1.726  Wärmeenergie-Unternehmen·Stromversorgungsunter...
# 32      1,3|90                        Stromversorgungsunternehmen
# 33   1,2|2.239                        Stromversorgungsunternehmen
# 34       0,0|0                        Stromversorgungsunternehmen
# 35       0,0|0  Gasversorgungsunternehmen·Ökostromanbieter·Str...
# 36       0,0|0  Energieanbieter·Stromversorgungsunternehmen·Ve...
#
#                                               comment
# 0   https://de.trustpilot.com/review/octopusenergy.de
# 1          https://de.trustpilot.com/review/ostrom.de
# 2    https://de.trustpilot.com/review/rabot-charge.de
# 3   https://de.trustpilot.com/review/montana-energ...
# 4             https://de.trustpilot.com/review/eon.de
# 5   https://de.trustpilot.com/review/www.gruenwelt.de
# 6   https://de.trustpilot.com/review/rheinenergie.com
# 7    https://de.trustpilot.com/review/www.badenova.de
# 8   https://de.trustpilot.com/review/www.prizewize.de
# 9      https://de.trustpilot.com/review/dfm-select.de
# 10  https://de.trustpilot.com/review/www.vattenfal...
# 11  https://de.trustpilot.com/review/erdgas-suedwe...
# 12       https://de.trustpilot.com/review/zenstrom.de
# 13    https://de.trustpilot.com/review/veganstrom.com
# 14  https://de.trustpilot.com/review/fairtradepowe...
# 15         https://de.trustpilot.com/review/lekker.de
# 16   https://de.trustpilot.com/review/1komma5grad.com
# 17    https://de.trustpilot.com/review/paketsparer.de
# 18  https://de.trustpilot.com/review/www.new-energ...
# 19        https://de.trustpilot.com/review/www.swk.de
# 20  https://de.trustpilot.com/review/www.gas-und-s...
# 21  https://de.trustpilot.com/review/www.nowenergy.de
# 22      https://de.trustpilot.com/review/www.chono.de
# 23   https://de.trustpilot.com/review/getfresh.energy
# 24  https://de.trustpilot.com/review/polarstern-en...
# 25     https://de.trustpilot.com/review/primastrom.de
# 26         https://de.trustpilot.com/review/eprimo.de
# 27  https://de.trustpilot.com/review/www.voxenergi...
# 28         https://de.trustpilot.com/review/lition.de
# 29     https://de.trustpilot.com/review/oekostrom.com
# 30      https://de.trustpilot.com/review/mep-werke.de
# 31     https://de.trustpilot.com/review/lichtblick.de
# 32        https://de.trustpilot.com/review/www.rwe.de
# 33        https://de.trustpilot.com/review/www.ewe.de
# 34  https://de.trustpilot.com/review/mein-stromgas.de
# 35      https://de.trustpilot.com/review/optum-eba.de
# 36  https://de.trustpilot.com/review/netzberatung....

# %%
# Saving the new data frame before going on with the next steps
ener_suppliers.to_csv("ener_suppliers_raw.csv", index=False)

# %% [markdown]
# ### Define function to automate process

# %%
import requests
from bs4 import BeautifulSoup
import csv
import re

base_url = "https://de.trustpilot.com/categories/electric_utility_company"

def scrap_ener(): 
    csv_file = open("fliplart-data.csv", "a")
    writer = csv.writer(csv_file)

    writer.writerow(
        ['Product_name', 'Price', 'Rating', 'Product-url'])

    for page in range(1, 510):

        page = base_url + str(page)

        response = requests.get(page).text

        soup = BeautifulSoup(response, 'lxml')

        for product_urls in soup.find_all('a', href=True, attrs={'class': '_1fQZEK'}):
            
            #name
            try:
                name = product_urls.find('div', attrs={'class': '_4rR01T'}).text
            except Exception as e:
                name = "Not Available"

            #price
            try:
                price = product_urls.find('div', attrs={'class': '_30jeq3 _1_WHN1'}).text
                price = re.split("\₹", price)
                price = price[-1]
            except Exception as e:
                price = "Not Available"

            #rating
            try:
                rating = product_urls.find('div', attrs={'class': '_3LWZlK'}).text
            except Exception as e:
                rating = "Not Available"
            #item_url
            try:
                item_url = soup.find('a', class_="_1fQZEK", target="_blank")['href']
                item_url = " https://www.flipkart.com" + item_url
                item_url = re.split("\&", item_url)
                item_url = item_url[0]
            except Exception as e:
                item_url = "Not Available"

            print(f'Product name is {name}')
            print(f'Product price is {price}')
            print(f'Product rating is {rating}')
            print(f'Product url is {item_url}')


            writer.writerow(
                [name, price, rating, item_url])

# %%
import requests
from bs4 import BeautifulSoup
import csv
import re

base_url = "https://de.trustpilot.com/categories/electric_utility_company"

def get_urls(): 
    csv_file = open("fliplart-data.csv", "a")
    writer = csv.writer(csv_file)

    writer.writerow(
        ['Product_name', 'Price', 'Rating', 'Product-url'])

    for page in range(1, 510):

        page = base_url + str(page)

        response = requests.get(page).text

        soup = BeautifulSoup(response, 'lxml')

        for product_urls in soup.find_all('a', href=True, attrs={'class': '_1fQZEK'}):
            
            #name
            try:
                name = product_urls.find('div', attrs={'class': '_4rR01T'}).text
            except Exception as e:
                name = "Not Available"

            #price
            try:
                price = product_urls.find('div', attrs={'class': '_30jeq3 _1_WHN1'}).text
                price = re.split("\₹", price)
                price = price[-1]
            except Exception as e:
                price = "Not Available"

            #rating
            try:
                rating = product_urls.find('div', attrs={'class': '_3LWZlK'}).text
            except Exception as e:
                rating = "Not Available"
            #item_url
            try:
                item_url = soup.find('a', class_="_1fQZEK", target="_blank")['href']
                item_url = " https://www.flipkart.com" + item_url
                item_url = re.split("\&", item_url)
                item_url = item_url[0]
            except Exception as e:
                item_url = "Not Available"

            print(f'Product name is {name}')
            print(f'Product price is {price}')
            print(f'Product rating is {rating}')
            print(f'Product url is {item_url}')


            writer.writerow(
                [name, price, rating, item_url])

# %% [markdown]
# ### Clean data frame

# %%
df = ener_suppliers

# %%
df.head()
# Out:
#                         supplier               location score_votes  \
# 0         Octopus Energy Germany   München, Deutschland   4,8|8.392
# 1                         Ostrom    Berlin, Deutschland   4,8|1.607
# 2                   Rabot Charge   Hamburg, Deutschland     4,3|176
# 3                  MONTANA Group  Grünwald, Deutschland   4,0|3.153
# 4  E.ON Energie Deutschland GmbH   München, Deutschland  3,7|13.467
#
#                                                  cat  \
# 0  Stromversorgungsunternehmen·Energieversorger·E...
# 1  Ökostromanbieter·Stromversorgungsunternehmen·E...
# 2  Ökostromanbieter·Energieanbieter·Energieversor...
# 3  Kraftstofflieferant·Energieanbieter·Stromverso...
# 4  Solartechnikanbieter·Energieanbieter·Stromvers...
#
#                                              comment
# 0  https://de.trustpilot.com/review/octopusenergy.de
# 1         https://de.trustpilot.com/review/ostrom.de
# 2   https://de.trustpilot.com/review/rabot-charge.de
# 3  https://de.trustpilot.com/review/montana-energ...
# 4            https://de.trustpilot.com/review/eon.de

# %%
## separate scores and votes in 2 separate columns score and votes
df[['score', 'votes']] = df['score_votes'].apply(lambda x: pd.Series(str(x).split("|")))

# remove column score_votes
df = df.drop(['score_votes'], axis= 1)

#check
df.head()
# Out:
#                         supplier               location  \
# 0         Octopus Energy Germany   München, Deutschland
# 1                         Ostrom    Berlin, Deutschland
# 2                   Rabot Charge   Hamburg, Deutschland
# 3                  MONTANA Group  Grünwald, Deutschland
# 4  E.ON Energie Deutschland GmbH   München, Deutschland
#
#                                                  cat  \
# 0  Stromversorgungsunternehmen·Energieversorger·E...
# 1  Ökostromanbieter·Stromversorgungsunternehmen·E...
# 2  Ökostromanbieter·Energieanbieter·Energieversor...
# 3  Kraftstofflieferant·Energieanbieter·Stromverso...
# 4  Solartechnikanbieter·Energieanbieter·Stromvers...
#
#                                              comment score   votes
# 0  https://de.trustpilot.com/review/octopusenergy.de   4,8   8.392
# 1         https://de.trustpilot.com/review/ostrom.de   4,8   1.607
# 2   https://de.trustpilot.com/review/rabot-charge.de   4,3     176
# 3  https://de.trustpilot.com/review/montana-energ...   4,0   3.153
# 4            https://de.trustpilot.com/review/eon.de   3,7  13.467

# %%
## Alternate solution: separate scores and votes in 2 separate columns score and votes
# copy column
#df['votes'] = df['score_votes']

# remove first 4 strings to receive votes
#df['votes'] = df['votes'].str[4:]

# keep first 4 strings to keep score
#df['score_votes'] = df['score_votes'].str[:3]

# rename column
#df = df.rename(columns={'score_votes': 'score'})

#check
#df.head()

# %%
## change datatypes to float for score and change decimal separator to '.'
df['score'] = df['score'].str.replace(",",".")
df['score'] = df['score'].astype('float')
df.tail()
# Out:
#          supplier              location  \
# 32            RWE    Essen, Deutschland
# 33            EWE
# 34  Mein Stromgas  Dorsten, Deutschland
# 35     OPTUM GmbH
# 36   Netzberatung   Kassel, Deutschland
#
#                                                   cat  \
# 32                        Stromversorgungsunternehmen
# 33                        Stromversorgungsunternehmen
# 34                        Stromversorgungsunternehmen
# 35  Gasversorgungsunternehmen·Ökostromanbieter·Str...
# 36  Energieanbieter·Stromversorgungsunternehmen·Ve...
#
#                                               comment  score  votes
# 32        https://de.trustpilot.com/review/www.rwe.de    1.3     90
# 33        https://de.trustpilot.com/review/www.ewe.de    1.2  2.239
# 34  https://de.trustpilot.com/review/mein-stromgas.de    0.0      0
# 35      https://de.trustpilot.com/review/optum-eba.de    0.0      0
# 36  https://de.trustpilot.com/review/netzberatung....    0.0      0

# %%
## remove '.' from votes and change data type to integer
df['votes'] = df['votes'].str.replace(".","")
df['votes'] = df['votes'].astype('int64')
df.head()
# Out:
# /tmp/ipykernel_328/539288907.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['votes'] = df['votes'].str.replace(".","")
#                         supplier               location  \
# 0         Octopus Energy Germany   München, Deutschland
# 1                         Ostrom    Berlin, Deutschland
# 2                   Rabot Charge   Hamburg, Deutschland
# 3                  MONTANA Group  Grünwald, Deutschland
# 4  E.ON Energie Deutschland GmbH   München, Deutschland
#
#                                                  cat  \
# 0  Stromversorgungsunternehmen·Energieversorger·E...
# 1  Ökostromanbieter·Stromversorgungsunternehmen·E...
# 2  Ökostromanbieter·Energieanbieter·Energieversor...
# 3  Kraftstofflieferant·Energieanbieter·Stromverso...
# 4  Solartechnikanbieter·Energieanbieter·Stromvers...
#
#                                              comment  score  votes
# 0  https://de.trustpilot.com/review/octopusenergy.de    4.8   8392
# 1         https://de.trustpilot.com/review/ostrom.de    4.8   1607
# 2   https://de.trustpilot.com/review/rabot-charge.de    4.3    176
# 3  https://de.trustpilot.com/review/montana-energ...    4.0   3153
# 4            https://de.trustpilot.com/review/eon.de    3.7  13467

# %%
## Split location into two columns use apply()
df[['city', 'country']] = df['location'].apply(lambda x: pd.Series(str(x).split(",")))

# replace " " before country name
df['country'] = df['country'].str.replace(" ","")

# remove column location
df = df.drop(['location'], axis= 1)

#check
df.head()
# Out:
#                         supplier  \
# 0         Octopus Energy Germany
# 1                         Ostrom
# 2                   Rabot Charge
# 3                  MONTANA Group
# 4  E.ON Energie Deutschland GmbH
#
#                                                  cat  \
# 0  Stromversorgungsunternehmen·Energieversorger·E...
# 1  Ökostromanbieter·Stromversorgungsunternehmen·E...
# 2  Ökostromanbieter·Energieanbieter·Energieversor...
# 3  Kraftstofflieferant·Energieanbieter·Stromverso...
# 4  Solartechnikanbieter·Energieanbieter·Stromvers...
#
#                                              comment  score  votes      city  \
# 0  https://de.trustpilot.com/review/octopusenergy.de    4.8   8392   München
# 1         https://de.trustpilot.com/review/ostrom.de    4.8   1607    Berlin
# 2   https://de.trustpilot.com/review/rabot-charge.de    4.3    176   Hamburg
# 3  https://de.trustpilot.com/review/montana-energ...    4.0   3153  Grünwald
# 4            https://de.trustpilot.com/review/eon.de    3.7  13467   München
#
#         country
# 0   Deutschland
# 1   Deutschland
# 2   Deutschland
# 3   Deutschland
# 4   Deutschland

# %%
# replace "·" before in column cat with " "
df['cat'] = df['cat'].str.replace("·"," ")

# %%
# check
df.head()
# Out:
#                         supplier  \
# 0         Octopus Energy Germany
# 1                         Ostrom
# 2                   Rabot Charge
# 3                  MONTANA Group
# 4  E.ON Energie Deutschland GmbH
#
#                                                  cat  \
# 0  Stromversorgungsunternehmen Energieversorger E...
# 1  Ökostromanbieter Stromversorgungsunternehmen E...
# 2  Ökostromanbieter Energieanbieter Energieversor...
# 3  Kraftstofflieferant Energieanbieter Stromverso...
# 4  Solartechnikanbieter Energieanbieter Stromvers...
#
#                                              comment  score  votes      city  \
# 0  https://de.trustpilot.com/review/octopusenergy.de    4.8   8392   München
# 1         https://de.trustpilot.com/review/ostrom.de    4.8   1607    Berlin
# 2   https://de.trustpilot.com/review/rabot-charge.de    4.3    176   Hamburg
# 3  https://de.trustpilot.com/review/montana-energ...    4.0   3153  Grünwald
# 4            https://de.trustpilot.com/review/eon.de    3.7  13467   München
#
#         country
# 0   Deutschland
# 1   Deutschland
# 2   Deutschland
# 3   Deutschland
# 4   Deutschland

# %%
##  rearrange order of columns
# get columns list
cols = df.columns.tolist()
cols
# Out:
# ['supplier', 'cat', 'comment', 'score', 'votes', 'city', 'country']

# %%
#create new list with updated order
cols_new = ['supplier', 'city', 'country', 'cat', 'score', 'votes', 'comment']

#rearrange columns
df = df[cols_new]

#check
df.head()
# Out:
#                         supplier      city       country  \
# 0         Octopus Energy Germany   München   Deutschland
# 1                         Ostrom    Berlin   Deutschland
# 2                   Rabot Charge   Hamburg   Deutschland
# 3                  MONTANA Group  Grünwald   Deutschland
# 4  E.ON Energie Deutschland GmbH   München   Deutschland
#
#                                                  cat  score  votes  \
# 0  Stromversorgungsunternehmen Energieversorger E...    4.8   8392
# 1  Ökostromanbieter Stromversorgungsunternehmen E...    4.8   1607
# 2  Ökostromanbieter Energieanbieter Energieversor...    4.3    176
# 3  Kraftstofflieferant Energieanbieter Stromverso...    4.0   3153
# 4  Solartechnikanbieter Energieanbieter Stromvers...    3.7  13467
#
#                                              comment
# 0  https://de.trustpilot.com/review/octopusenergy.de
# 1         https://de.trustpilot.com/review/ostrom.de
# 2   https://de.trustpilot.com/review/rabot-charge.de
# 3  https://de.trustpilot.com/review/montana-energ...
# 4            https://de.trustpilot.com/review/eon.de

# %%
#check transformation with info
df.info()
# no missing values, dtypes correct
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   supplier  37 non-null     object
#  1   city      37 non-null     object
#  2   country   31 non-null     object
#  3   cat       37 non-null     object
#  4   score     37 non-null     float64
#  5   votes     37 non-null     int64
#  6   comment   37 non-null     object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 2.2+ KB

# %%
df.describe()
# Out:
#            score         votes
# count  37.000000     37.000000
# mean    2.964865   1505.243243
# std     1.457779   3240.455218
# min     0.000000      0.000000
# 25%     1.900000     39.000000
# 50%     3.400000    125.000000
# 75%     4.000000    961.000000
# max     4.800000  13467.000000

# %%
display(df)
# Out:
#                              supplier                  city       country  \
# 0              Octopus Energy Germany               München   Deutschland
# 1                              Ostrom                Berlin   Deutschland
# 2                        Rabot Charge               Hamburg   Deutschland
# 3                       MONTANA Group              Grünwald   Deutschland
# 4       E.ON Energie Deutschland GmbH               München   Deutschland
# 5                    Grünwelt Energie                Kaarst   Deutschland
# 6                        RheinEnergie                  Köln   Deutschland
# 7                            badenova  Freiburg im Breisgau   Deutschland
# 8                        pricewise.de            Heidelberg   Deutschland
# 9                     DFM-Select GmbH             Metzingen   Deutschland
# 10       Vattenfall Europe Sales GmbH                                 NaN
# 11                Erdgas Südwest GmbH             Ettlingen   Deutschland
# 12                           Zenstrom                Berlin   Deutschland
# 13                         VeganStrom                Berlin   Deutschland
# 14  Fair Trade Power Deutschland GmbH               München   Deutschland
# 15                Lekker Energie GmbH                Berlin   Deutschland
# 16                           1KOMMA5°               Hamburg   Deutschland
# 17                        Paketsparer                Berlin   Deutschland
# 18                        NEW Energie       Mönchengladbach   Deutschland
# 19                   SWK ENERGIE GmbH               Krefeld   Deutschland
# 20          Gas-und-Stromvergleich.de                                 NaN
# 21                          nowenergy                Berlin   Deutschland
# 22                        CHONO MEDIA                                 NaN
# 23                       Fresh Energy                Berlin   Deutschland
# 24                 Polarstern Energie               München   Deutschland
# 25                         Primastrom                Berlin   Deutschland
# 26                        eprimo GmbH          Neu-Isenburg   Deutschland
# 27                         voxenergie                Berlin   Deutschland
# 28                     Lition Energie                Berlin   Deutschland
# 29                          Oekostrom                                 NaN
# 30                          MEP Werke           Eckernförde   Deutschland
# 31                         LichtBlick               Hamburg   Deutschland
# 32                                RWE                 Essen   Deutschland
# 33                                EWE                                 NaN
# 34                      Mein Stromgas               Dorsten   Deutschland
# 35                         OPTUM GmbH                                 NaN
# 36                       Netzberatung                Kassel   Deutschland
#
#                                                   cat  score  votes  \
# 0   Stromversorgungsunternehmen Energieversorger E...    4.8   8392
# 1   Ökostromanbieter Stromversorgungsunternehmen E...    4.8   1607
# 2   Ökostromanbieter Energieanbieter Energieversor...    4.3    176
# 3   Kraftstofflieferant Energieanbieter Stromverso...    4.0   3153
# 4   Solartechnikanbieter Energieanbieter Stromvers...    3.7  13467
# 5                         Stromversorgungsunternehmen    3.6   1966
# 6   Stromversorgungsunternehmen Energieanbieter Ök...    3.4    547
# 7   Stromversorgungsunternehmen Ökostromanbieter G...    2.8    242
# 8   Gasversorgungsunternehmen Stromversorgungsunte...    4.8    119
# 9   Anbieter von Elektronikbauteilen Technischer K...    4.6     22
# 10  Stromversorgungsunternehmen Gasversorgungsunte...    4.4  10260
# 11  Ökostromanbieter Gasversorgungsunternehmen Str...    4.4     46
# 12  Energieanbieter Ökostromanbieter Stromversorgu...    4.0     89
# 13  Stromversorgungsunternehmen Ökostromanbieter E...    4.0     30
# 14  Stromversorgungsunternehmen Ökostromanbieter E...    4.0      3
# 15  Energieanbieter Gasversorgungsunternehmen Stro...    3.9    224
# 16  Energieanlagen und -lösungen Stromversorgungsu...    3.8     15
# 17  Telekommunikationsanbieter Internetanbieter Te...    3.7     49
# 18                        Stromversorgungsunternehmen    3.6    618
# 19  Stadtwerke Ökostromanbieter Stromversorgungsun...    3.6    140
# 20  Stromversorgungsunternehmen Gasversorgungsunte...    0.0      0
# 21  Gasversorgungsunternehmen Stromversorgungsunte...    3.4     81
# 22  Reiseanbieter Telekommunikationsanbieter Strom...    3.2     39
# 23                        Stromversorgungsunternehmen    3.1     68
# 24  Energieanbieter Ökostromanbieter Stromversorgu...    3.1     32
# 25  Stromversorgungsunternehmen Telekommunikations...    2.8    127
# 26  Stromversorgungsunternehmen Energieversorger G...    2.6   8863
# 27  Internetanbieter Stromversorgungsunternehmen G...    2.4    133
# 28                        Stromversorgungsunternehmen    1.9    125
# 29  Gasversorgungsunternehmen Stromversorgungsunte...    1.7     45
# 30                        Stromversorgungsunternehmen    1.5    961
# 31  Wärmeenergie-Unternehmen Stromversorgungsunter...    1.3   1726
# 32                        Stromversorgungsunternehmen    1.3     90
# 33                        Stromversorgungsunternehmen    1.2   2239
# 34                        Stromversorgungsunternehmen    0.0      0
# 35  Gasversorgungsunternehmen Ökostromanbieter Str...    0.0      0
# 36  Energieanbieter Stromversorgungsunternehmen Ve...    0.0      0
#
#                                               comment
# 0   https://de.trustpilot.com/review/octopusenergy.de
# 1          https://de.trustpilot.com/review/ostrom.de
# 2    https://de.trustpilot.com/review/rabot-charge.de
# 3   https://de.trustpilot.com/review/montana-energ...
# 4             https://de.trustpilot.com/review/eon.de
# 5   https://de.trustpilot.com/review/www.gruenwelt.de
# 6   https://de.trustpilot.com/review/rheinenergie.com
# 7    https://de.trustpilot.com/review/www.badenova.de
# 8   https://de.trustpilot.com/review/www.prizewize.de
# 9      https://de.trustpilot.com/review/dfm-select.de
# 10  https://de.trustpilot.com/review/www.vattenfal...
# 11  https://de.trustpilot.com/review/erdgas-suedwe...
# 12       https://de.trustpilot.com/review/zenstrom.de
# 13    https://de.trustpilot.com/review/veganstrom.com
# 14  https://de.trustpilot.com/review/fairtradepowe...
# 15         https://de.trustpilot.com/review/lekker.de
# 16   https://de.trustpilot.com/review/1komma5grad.com
# 17    https://de.trustpilot.com/review/paketsparer.de
# 18  https://de.trustpilot.com/review/www.new-energ...
# 19        https://de.trustpilot.com/review/www.swk.de
# 20  https://de.trustpilot.com/review/www.gas-und-s...
# 21  https://de.trustpilot.com/review/www.nowenergy.de
# 22      https://de.trustpilot.com/review/www.chono.de
# 23   https://de.trustpilot.com/review/getfresh.energy
# 24  https://de.trustpilot.com/review/polarstern-en...
# 25     https://de.trustpilot.com/review/primastrom.de
# 26         https://de.trustpilot.com/review/eprimo.de
# 27  https://de.trustpilot.com/review/www.voxenergi...
# 28         https://de.trustpilot.com/review/lition.de
# 29     https://de.trustpilot.com/review/oekostrom.com
# 30      https://de.trustpilot.com/review/mep-werke.de
# 31     https://de.trustpilot.com/review/lichtblick.de
# 32        https://de.trustpilot.com/review/www.rwe.de
# 33        https://de.trustpilot.com/review/www.ewe.de
# 34  https://de.trustpilot.com/review/mein-stromgas.de
# 35      https://de.trustpilot.com/review/optum-eba.de
# 36  https://de.trustpilot.com/review/netzberatung....

# %% [markdown]
# ### Final CSV of energy supplier ratings Germany for export

# %%
# Saving the cleaned data frame in a csv file
df.to_csv("ener_supplier_rankings_clean.csv", index=False)
