# %% [markdown]
# # Scraping posts for all German energy suppliers at Trustpilot using BeautifulSoup

# %% [markdown]
# Author: Matthias Isele

# %% [markdown]
# This notebook scrapes posts for all German energy suppliers at Trustpilot.
#
# The goal is to extract for each company all customer post in hindsight of
#
# - Customer nickname (nickname)
# - Location of Customer (location)
# - number of stars (stars)
# - Headline of post (headline)
# - Date of post (dop)
# - Date of experience (doe)
# - If there is one: Comment of customer (comment)
# - If there is one: Answer of eon (answer)
# - If there is one: Date of answer (doa)
#
# There is a random time delay implemented to avoid the error 'HTTP Error 403: Forbidden'. This error appears because Trustpilot blocks users that gather too much data per time.

# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup as bs

import numpy as np
import pandas as pd

import time
import random

# %% [markdown]
# We will iterate over the following list of energy suppliers which was automatically scraped by Stefanies notebook.

# %%
energy_suppliers=pd.read_csv('C:/Users/isele/OneDrive/Desktop/Supply Chain - Customer Satisfaction/Data/ener_supplier_rankings_clean.csv')
display(energy_suppliers)
# Out:
#                              supplier                  city       country  \
# 0              Octopus Energy Germany               München   Deutschland
# 1                              Ostrom                Berlin   Deutschland
# 2                        Rabot Charge               Hamburg   Deutschland
# 3                       MONTANA Group              Grünwald   Deutschland
# 4       E.ON Energie Deutschland GmbH               München   Deutschland
# 5                    Grünwelt Energie                Kaarst   Deutschland
# 6                        RheinEnergie                  Köln   Deutschland
# 7                            badenova  Freiburg im Breisgau   Deutschland
# 8                        pricewise.de            Heidelberg   Deutschland
# 9                     DFM-Select GmbH             Metzingen   Deutschland
# 10       Vattenfall Europe Sales GmbH                   NaN           NaN
# 11                Erdgas Südwest GmbH             Ettlingen   Deutschland
# 12                           Zenstrom                Berlin   Deutschland
# 13                         VeganStrom                Berlin   Deutschland
# 14  Fair Trade Power Deutschland GmbH               München   Deutschland
# 15                Lekker Energie GmbH                Berlin   Deutschland
# 16                        Paketsparer                Berlin   Deutschland
# 17                        NEW Energie       Mönchengladbach   Deutschland
# 18                   SWK ENERGIE GmbH               Krefeld   Deutschland
# 19          Gas-und-Stromvergleich.de                   NaN           NaN
# 20                          nowenergy                Berlin   Deutschland
# 21                           1KOMMA5°               Hamburg   Deutschland
# 22                        CHONO MEDIA                   NaN           NaN
# 23                       Fresh Energy                Berlin   Deutschland
# 24                 Polarstern Energie               München   Deutschland
# 25                         Primastrom                Berlin   Deutschland
# 26                        eprimo GmbH          Neu-Isenburg   Deutschland
# 27                         voxenergie                Berlin   Deutschland
# 28                     Lition Energie                Berlin   Deutschland
# 29                          Oekostrom                   NaN           NaN
# 30                          MEP Werke           Eckernförde   Deutschland
# 31                         LichtBlick               Hamburg   Deutschland
# 32                                RWE                 Essen   Deutschland
# 33                                EWE                   NaN           NaN
# 34                         OPTUM GmbH                   NaN           NaN
# 35                      Mein Stromgas               Dorsten   Deutschland
# 36                       Netzberatung                Kassel   Deutschland
#
#                                                   cat  score  votes  \
# 0   Ökostromanbieter Energieanbieter Stromversorgu...    4.8   8042
# 1   Energieanbieter Ökostromanbieter Stromversorgu...    4.8   1598
# 2   Energieversorger Energieanbieter Stromversorgu...    4.3    174
# 15         https://de.trustpilot.com/review/lekker.de
# 16    https://de.trustpilot.com/review/paketsparer.de
# 17  https://de.trustpilot.com/review/www.new-energ...
# 18        https://de.trustpilot.com/review/www.swk.de
# 19  https://de.trustpilot.com/review/www.gas-und-s...
# 20  https://de.trustpilot.com/review/www.nowenergy.de
# 21   https://de.trustpilot.com/review/1komma5grad.com
# 22      https://de.trustpilot.com/review/www.chono.de
# 23   https://de.trustpilot.com/review/getfresh.energy
# 24  https://de.trustpilot.com/review/polarstern-en...
# 25     https://de.trustpilot.com/review/primastrom.de
# 26         https://de.trustpilot.com/review/eprimo.de
# 27  https://de.trustpilot.com/review/www.voxenergi...
# 28         https://de.trustpilot.com/review/lition.de
# 29     https://de.trustpilot.com/review/oekostrom.com
# 30      https://de.trustpilot.com/review/mep-werke.de
# 31     https://de.trustpilot.com/review/lichtblick.de
# 32        https://de.trustpilot.com/review/www.rwe.de
# 33        https://de.trustpilot.com/review/www.ewe.de
# 34      https://de.trustpilot.com/review/optum-eba.de
# 35  https://de.trustpilot.com/review/mein-stromgas.de
# 36  https://de.trustpilot.com/review/netzberatung....

# %% [markdown]
# To simplify scraping we split the DataFrame based on number of votes.

# %%
#drop companies with zero votes 
es=energy_suppliers.drop(energy_suppliers[energy_suppliers['votes'] == 0].index)
es.reset_index(inplace=True, drop=True) 
#display(es)

# %%
#companies with less equal than 250 votes
es_leq250=es[es['votes']<=250]
es_leq250.reset_index(inplace=True, drop=True)

#companies with votes between 250 and 2500
es_leq4000=es[(250<es['votes'])&(es['votes']<=4000)]
es_leq4000.reset_index(inplace=True, drop=True)

#companies with more than 2500 votes
es_geq4000=es[4000<es['votes']]
es_geq4000.reset_index(inplace=True, drop=True)

# %%
display(es_leq250)
display(es_leq4000)
display(es_geq4000)
# Out:
#                              supplier                  city       country  \
# 0                        Rabot Charge               Hamburg   Deutschland
# 1                            badenova  Freiburg im Breisgau   Deutschland
# 2                        pricewise.de            Heidelberg   Deutschland
# 3                     DFM-Select GmbH             Metzingen   Deutschland
# 4                 Erdgas Südwest GmbH             Ettlingen   Deutschland
# 5                            Zenstrom                Berlin   Deutschland
# 6                          VeganStrom                Berlin   Deutschland
# 7   Fair Trade Power Deutschland GmbH               München   Deutschland
# 8                 Lekker Energie GmbH                Berlin   Deutschland
# 9                         Paketsparer                Berlin   Deutschland
# 10                   SWK ENERGIE GmbH               Krefeld   Deutschland
# 11                          nowenergy                Berlin   Deutschland
# 12                           1KOMMA5°               Hamburg   Deutschland
# 13                        CHONO MEDIA                   NaN           NaN
# 14                       Fresh Energy                Berlin   Deutschland
# 15                 Polarstern Energie               München   Deutschland
# 16                         Primastrom                Berlin   Deutschland
# 17                         voxenergie                Berlin   Deutschland
# 18                     Lition Energie                Berlin   Deutschland
# 19                          Oekostrom                   NaN           NaN
# 20                                RWE                 Essen   Deutschland
#
#                                                   cat  score  votes  \
# 0   Energieversorger Energieanbieter Stromversorgu...    4.3    174
# 1   Stromversorgungsunternehmen Energieanbieter Ga...    2.7    241
# 5                        Stromversorgungsunternehmen    1.5    961
# 6  Stromversorgungsunternehmen Energieanbieter Ök...    1.3   1708
# 7                        Stromversorgungsunternehmen    1.2   2228
#
#                                              comment
# 0         https://de.trustpilot.com/review/ostrom.de
# 1  https://de.trustpilot.com/review/montana-energ...
# 2  https://de.trustpilot.com/review/www.gruenwelt.de
# 3  https://de.trustpilot.com/review/rheinenergie.com
# 4  https://de.trustpilot.com/review/www.new-energ...
# 5      https://de.trustpilot.com/review/mep-werke.de
# 6     https://de.trustpilot.com/review/lichtblick.de
# 7        https://de.trustpilot.com/review/www.ewe.de
#                         supplier          city       country  \
# 0         Octopus Energy Germany       München   Deutschland
# 1  E.ON Energie Deutschland GmbH       München   Deutschland
# 2   Vattenfall Europe Sales GmbH           NaN           NaN
# 3                    eprimo GmbH  Neu-Isenburg   Deutschland
#
#                                                  cat  score  votes  \
# 0  Ökostromanbieter Energieanbieter Stromversorgu...    4.8   8042
# 1  Energieversorger Stromversorgungsunternehmen Ö...    3.7  13223
# 2  Stromversorgungsunternehmen Gasversorgungsunte...    4.4  10204
# 3  Energieanbieter Gasversorgungsunternehmen Stro...    2.6   8786
#
#                                              comment
# 0  https://de.trustpilot.com/review/octopusenergy.de
# 1            https://de.trustpilot.com/review/eon.de
# 2  https://de.trustpilot.com/review/www.vattenfal...
# 3         https://de.trustpilot.com/review/eprimo.de

# %%
#pd.set_option('display.max_colwidth', -1) 
#pd.reset_option('display.max_colwidth')
#df_final

# %% [markdown]
# We scrape, clean and save the result with the help of the following function. The boolean parameter 'sleep' aktivates or deactivates a random time delay between three and five seconds per iteration.

# %%
def scrape_clean_save(company,url1,sleep):
    
    #SCRAPE------------------------------------------------------------------------------------------------------------------
    #Find number of pages for fixed energy supplier
    page1 = urlopen(url1)
    soup1 = bs(page1, "html.parser")

    navigation=soup1.find('nav',{'role':'navigation'}).findAll('span',{'class':'typography_heading-xxs__QKBS8 typography_appearance-inherit__D7XqR typography_disableResponsiveSizing__OuNP7'})
    n_pages=int(navigation[-2].text)#number of pages

    #Iterating over pages
    start_page=1 #included
    end_page=n_pages #included

    #The following list will collect a DataFrame for each page.
    df=[]

    for n in range(start_page,end_page+1):

        url = url1+'?page='+str(n)
        req = Request(url , headers={'User-Agent': 'Mozilla/5.0'})

        #Implement try and catch
        try:
            page = urlopen(req).read()
            soup = bs(page, 'html.parser')
            card_list=soup.findAll('div', {'class': 'styles_reviewCardInner__EwDq2'})

            #Create the DataFrame
            nickname=[]
            location=[]
            stars=[]
            headline=[]
            dop=[]
            doe=[]
            comment=[]
            answer=[]
            doa=[]

            for card in card_list:

                nickname.append(card.find('span', {'class': 'typography_heading-xxs__QKBS8 typography_appearance-default__AAY17'}).text)

                location.append(card.find('div', {'class': 'typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_detailsIcon__Fo_ua'}).find('span').text)

                stars.append(card.find('div', {'class': 'star-rating_starRating__4rrcf star-rating_medium__iN6Ty'}).find('img')['alt'])

                headline.append(card.find('h2', {'class': 'typography_heading-s__f7029 typography_appearance-default__AAY17'}).text)

                dop.append(card.find('time')['datetime'])

                doe.append(card.find('p', {'class': 'typography_body-m__xgxZ_ typography_appearance-default__AAY17'}).text)

                #Check, whether there is a comment before appending. If not, append 'None'.  
                if card.find('p', {'class': 'typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn'}):
                    comment.append(card.find('p', {'class': 'typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn'}).text)
                else: comment.append(None)

                #Check, whether there is an answer. If yes, append answer and doa. If no, append 'None' in both cases.                  
                if card.find('p', {'data-service-review-business-reply-text-typography': 'true'}):
                    answer.append(card.find('p', {'data-service-review-business-reply-text-typography': 'true'}).text)
                    doa.append(card.find('div',{'class':'styles_replyInfo__FYSje'}).find('time')['datetime'])
                else:
                    answer.append(None)
                    doa.append(None)



            column_names=['Nickname', 'Location', 'Stars','Headline','DoP','DoE','Comment','Answer','DoA']
            df_page=pd.DataFrame(list(zip(nickname, location, stars, headline, dop, doe, comment, answer, doa)), columns=column_names)
            df_page['Page']=n
            df.append(df_page)

        except:
            print(f'iteration stopped at page {n} and company {company}')
            break

        random_number = round(random.uniform(3, 5), 2)
        if sleep==True:
            time.sleep(random_number) # add stop of random duration between 3-5 seconds

    #Concatenate the list of DataFrames and reset index.
    df_concat=pd.concat(df)
    df_concat.reset_index(inplace=True, drop=True) 
        
    #CLEAN--------------------------------------------------------------------------------------------------------------
    df_cleaned=df_concat.copy()

    #Column 'Stars' should have values from 1 to 5
    df_cleaned['Stars']=df_cleaned['Stars'].apply(lambda x: x[13]).astype('int')


    #Split 'DoE' into 'DoE.day', 'DoE.month', 'DoE.Year' and convert 'DoE' to datetime.
    df_cleaned['DoE']=df_cleaned['DoE'].apply(lambda x: x[21:])
    df_cleaned[['DoE.day', 'DoE.month','DoE.year']] = df_cleaned['DoE'].str.split(' ', expand=True)
    months = {'Januar':'january', 'Februar':'february','März':'march','April':'april','Mai':'may','Juni':'june','Juli':'july','August':'august','September':'september','Oktober':'october','November':'november','Dezember':'december'}
    months_numbers = {'Januar':'1', 'Februar':'2','März':'3','April':'4','Mai':'5','Juni':'6','Juli':'7','August':'8','September':'9','Oktober':'10','November':'11','Dezember':'12'}
    df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
    df_cleaned=df_cleaned.replace({'DoE.month': months_numbers})
    df_cleaned['DoE']=pd.to_datetime(df_cleaned['DoE.month']+'-'+df_cleaned['DoE.day']+'-'+df_cleaned['DoE.year'])
    df_cleaned=df_cleaned.astype({'DoE.day': 'int', 'DoE.month': 'int', 'DoE.year': 'int'})


    #Convert DoP to datetime and create 'DoP.day', 'DoP.month', 'DoP.Year' 
    df_cleaned['DoP']=pd.to_datetime(df_cleaned['DoP'])
    df_cleaned['DoP.day']=df_cleaned['DoP'].apply(lambda x: x.day)
    df_cleaned['DoP.month']=df_cleaned['DoP'].apply(lambda x: x.month)
    df_cleaned['DoP.year']=df_cleaned['DoP'].apply(lambda x: x.year)


    #Convert DoA to datetime and create 'DoA.day', 'DoA.month', 'DoA.Year' 
    df_cleaned['DoA']=pd.to_datetime(df_cleaned['DoA'])
    df_cleaned['DoA.day']=df_cleaned['DoA'].apply(lambda x: x.day)
    df_cleaned['DoA.month']=df_cleaned['DoA'].apply(lambda x: x.month)
    df_cleaned['DoA.year']=df_cleaned['DoA'].apply(lambda x: x.year)


    #Clean Comments and Answers
    df_cleaned['Comment']= df_cleaned['Comment'].str.replace('\n', '')
    df_cleaned['Comment']= df_cleaned['Comment'].str.replace('\r', '')
    df_cleaned['Answer']= df_cleaned['Answer'].str.replace('\n', '')
    df_cleaned['Answer']= df_cleaned['Answer'].str.replace('\r', '')


    #Check whether there is comment or answer
    df_cleaned['Comment_TF']=df_cleaned['Comment'].apply(lambda x: 0 if x==None else 1)
    df_cleaned['Answer_TF']=df_cleaned['Answer'].apply(lambda x: 0 if x==None else 1)  
    
    #Note company
    df_cleaned['Company']=company
    
    #SAVE
    df_cleaned.to_csv('C:/Users/isele/OneDrive/Desktop/Supply Chain - Customer Satisfaction/Data/'+company+'.csv')

    return df_cleaned

# %% [markdown]
# First we scrape companies with less than 250 votes. As these are not many votes we can scrae over index ranges without sleep.

# %%
for k in range(len(es_leq250)):
    url1=(es_leq250['comment'])[k]
    company=(es_leq250['supplier'])[k]
    scrape_clean_save(company,url1,sleep=False)
# Out:
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# iteration stopped at page 7 and company voxenergie
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')

# %% [markdown]
# Next companies between 250 and 4000 votes. No sleep is necessary but we should scrape them single handedly.

# %%
#k ranges from 0 to 7
for k in range(2,len(es_leq4000)):
    url1=(es_leq4000['comment'])[k]
    company=(es_leq4000['supplier'])[k]
    scrape_clean_save(company,url1,sleep=False)
# Out:
# iteration stopped at page 5 and company Grünwelt Energie
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# iteration stopped at page 98 and company EWE
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')

# %% [markdown]
# Finally companies over 4000 votes. Sleep is necessary and they should be scraped them single handedly.

# %%
for k in range(len(es_geq4000)):
    url1=(es_geq4000['comment'])[k]
    company=(es_geq4000['supplier'])[k]
    scrape_clean_save(company,url1,sleep=True)
# Out:
# iteration stopped at page 97 and company Octopus Energy Germany
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# iteration stopped at page 312 and company E.ON Energie Deutschland GmbH
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\1523951693.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')

# %% [markdown]
# ### Retrieving the missing pages.

# %% [markdown]
# The missing pages will be retriefed by generalizing the above approach to select specific page ranges.

# %%
def scrape_clean_save_v2(company,url1,sleep=False,start_page=1,end_page=0,suffix=""):
    
    #SCRAPE------------------------------------------------------------------------------------------------------------------
    #Find number of pages for fixed energy supplier
    page1 = urlopen(url1)
    soup1 = bs(page1, "html.parser")

    navigation=soup1.find('nav',{'role':'navigation'}).findAll('span',{'class':'typography_heading-xxs__QKBS8 typography_appearance-inherit__D7XqR typography_disableResponsiveSizing__OuNP7'})
    n_pages=int(navigation[-2].text)#number of pages

    #Iterating over pages
    if end_page==0:
        end_page=n_pages #included

    #The following list will collect a DataFrame for each page.
    df=[]

    for n in range(start_page,end_page+1):

        url = url1+'?page='+str(n)
        req = Request(url , headers={'User-Agent': 'Mozilla/5.0'})

        #Implement try and catch
        try:
            page = urlopen(req).read()
            soup = bs(page, 'html.parser')
            card_list=soup.findAll('div', {'class': 'styles_reviewCardInner__EwDq2'})

            #Create the DataFrame
            nickname=[]
            location=[]
            stars=[]
            headline=[]
            dop=[]
            doe=[]
            comment=[]
            answer=[]
            doa=[]

            for card in card_list:

                nickname.append(card.find('span', {'class': 'typography_heading-xxs__QKBS8 typography_appearance-default__AAY17'}).text)

                #Check, whether there is a location
                if card.find('div', {'class': 'typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_detailsIcon__Fo_ua'}).find('span'):
                    location.append(card.find('div', {'class': 'typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_detailsIcon__Fo_ua'}).find('span').text)
                else:
                    location.append(None)
                    
                stars.append(card.find('div', {'class': 'star-rating_starRating__4rrcf star-rating_medium__iN6Ty'}).find('img')['alt'])

                headline.append(card.find('h2', {'class': 'typography_heading-s__f7029 typography_appearance-default__AAY17'}).text)

                dop.append(card.find('time')['datetime'])

                doe.append(card.find('p', {'class': 'typography_body-m__xgxZ_ typography_appearance-default__AAY17'}).text)

                #Check, whether there is a comment before appending. If not, append 'None'.  
                if card.find('p', {'class': 'typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn'}):
                    comment.append(card.find('p', {'class': 'typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn'}).text)
                else: comment.append(None)

                #Check, whether there is an answer. If yes, append answer and doa. If no, append 'None' in both cases.                  
                if card.find('p', {'data-service-review-business-reply-text-typography': 'true'}):
                    answer.append(card.find('p', {'data-service-review-business-reply-text-typography': 'true'}).text)
                    doa.append(card.find('div',{'class':'styles_replyInfo__FYSje'}).find('time')['datetime'])
                else:
                    answer.append(None)
                    doa.append(None)



            column_names=['Nickname', 'Location', 'Stars','Headline','DoP','DoE','Comment','Answer','DoA']
            df_page=pd.DataFrame(list(zip(nickname, location, stars, headline, dop, doe, comment, answer, doa)), columns=column_names)
            df_page['Page']=n
            df.append(df_page)

        except:
            print(f'iteration stopped at page {n} and company {company}')
            break

        random_number = round(random.uniform(3, 5), 2)
        if sleep==True:
            time.sleep(random_number) # add stop of random duration between 3-5 seconds

    #Concatenate the list of DataFrames and reset index.
    df_concat=pd.concat(df)
    df_concat.reset_index(inplace=True, drop=True) 
        
    #CLEAN--------------------------------------------------------------------------------------------------------------
    df_cleaned=df_concat.copy()

    #Column 'Stars' should have values from 1 to 5
    df_cleaned['Stars']=df_cleaned['Stars'].apply(lambda x: x[13]).astype('int')


    #Split 'DoE' into 'DoE.day', 'DoE.month', 'DoE.Year' and convert 'DoE' to datetime.
    df_cleaned['DoE']=df_cleaned['DoE'].apply(lambda x: x[21:])
    df_cleaned[['DoE.day', 'DoE.month','DoE.year']] = df_cleaned['DoE'].str.split(' ', expand=True)
    months = {'Januar':'january', 'Februar':'february','März':'march','April':'april','Mai':'may','Juni':'june','Juli':'july','August':'august','September':'september','Oktober':'october','November':'november','Dezember':'december'}
    months_numbers = {'Januar':'1', 'Februar':'2','März':'3','April':'4','Mai':'5','Juni':'6','Juli':'7','August':'8','September':'9','Oktober':'10','November':'11','Dezember':'12'}
    df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
    df_cleaned=df_cleaned.replace({'DoE.month': months_numbers})
    df_cleaned['DoE']=pd.to_datetime(df_cleaned['DoE.month']+'-'+df_cleaned['DoE.day']+'-'+df_cleaned['DoE.year'])
    df_cleaned=df_cleaned.astype({'DoE.day': 'int', 'DoE.month': 'int', 'DoE.year': 'int'})


    #Convert DoP to datetime and create 'DoP.day', 'DoP.month', 'DoP.Year' 
    df_cleaned['DoP']=pd.to_datetime(df_cleaned['DoP'])
    df_cleaned['DoP.day']=df_cleaned['DoP'].apply(lambda x: x.day)
    df_cleaned['DoP.month']=df_cleaned['DoP'].apply(lambda x: x.month)
    df_cleaned['DoP.year']=df_cleaned['DoP'].apply(lambda x: x.year)


    #Convert DoA to datetime and create 'DoA.day', 'DoA.month', 'DoA.Year' 
    df_cleaned['DoA']=pd.to_datetime(df_cleaned['DoA'])
    df_cleaned['DoA.day']=df_cleaned['DoA'].apply(lambda x: x.day)
    df_cleaned['DoA.month']=df_cleaned['DoA'].apply(lambda x: x.month)
    df_cleaned['DoA.year']=df_cleaned['DoA'].apply(lambda x: x.year)


    #Clean Comments and Answers
    df_cleaned['Comment']= df_cleaned['Comment'].str.replace('\n', '')
    df_cleaned['Comment']= df_cleaned['Comment'].str.replace('\r', '')
    df_cleaned['Answer']= df_cleaned['Answer'].str.replace('\n', '')
    df_cleaned['Answer']= df_cleaned['Answer'].str.replace('\r', '')


    #Check whether there is comment or answer
    df_cleaned['Comment_TF']=df_cleaned['Comment'].apply(lambda x: 0 if x==None else 1)
    df_cleaned['Answer_TF']=df_cleaned['Answer'].apply(lambda x: 0 if x==None else 1)  
    
    #Note company
    df_cleaned['Company']=company
    
    #SAVE
    df_cleaned.to_csv('C:/Users/isele/OneDrive/Desktop/Supply Chain - Customer Satisfaction/Data/'+company+suffix+'.csv')

    return df_cleaned

# %%
#voxenergie
k=17
url1=(es_leq250['comment'])[k]
company=(es_leq250['supplier'])[k]
scrape_clean_save_v2(company,url1,sleep=False,start_page=5,end_page=7,suffix='page_6_to_7')
# Out:
# iteration stopped at page 6 and company voxenergie
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\430334901.py:102: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
#                    Nickname Location  Stars  \
# 0                Uwe Müller       DE      1
# 1                    W Koch       DE      1
# 2               Gabi Nickel       DE      1
# 3             Reinhold Bert       DE      1
# 4           Emanuel Büttner       DE      4
# 5                  Scarlett       DE      1
# 6           Sasha Katharina       DE      4
# 7                    Dagmar       DE      1
# 8                       Lee       DE      1
# 9          Stephanie Luther       DE      1
# 10       Janna Elena Ahrens       DE      1
# 11                   Sigwin       DE      1
# 12  marcelleo90 marcelleo90       DE      5
# 13               Ari Schütz       DE      3
# 14            Petra Hartwig       DE      1
# 15               Scheehader       DE      1
# 16           Vincenzo Mauro       DE      1
# 17             Annett Opitz       DE      1
# 18                    MAC C       AE      1
# 19               Eddi Franz       DE      1
#
#                                              Headline  \
# 0                             Die fristlose Kündigung
# 1   Ein Verbrecherladen, mangelhafte Kundenbetreuu...
# 2                Wir haben jetzt Oktober .seit April…
# 3              Ich habe über Voxenergie meinen Strom…
# 4                                      Gut erreichbar
# 5   Extrem schlechter Kundensupport, kein Stück en...
# 6                           Bisher sind wir zufrieden
# 7       Schlimmer als die Hütchenspieler...FINGER WEG
# 8                                            VORSICHT
# 9                     Umzuziehen - eine Katastrophe!!
# 10                          Schreckliches Unternehmen
# 11                          Von Frechheit bis Abzocke
# 12                  Bin von Voxenergie sehr überzeugt
# 13                                   Router inklusive
# 14  Kündigungen werden ignoriert  Mehrere Male gek...
# 15                                           0 Sterne
# 16              Finger weg mir haben die ein Vertrag…
# 17                     Zahle seit einem Jahr für ein…
# 18                                  Komplett unseriös
# 19                                       DSL-Vertrag?
#
#                          DoP        DoE  \
# 0  2022-12-15 20:36:53+00:00 2022-12-14
# 1  2019-10-24 17:03:56+00:00 2019-10-24
# 12 2023-07-18 10:54:05+00:00     5  ...      2023        9          5
# 13                       NaT     5  ...      2023       20          7
# 14                       NaT     5  ...      2022       28          1
# 15                       NaT     5  ...      2022       16          3
# 16                       NaT     5  ...      2023       21          7
# 17                       NaT     5  ...      2019       25          9
# 18                       NaT     5  ...      2020       15          6
# 19                       NaT     5  ...      2019        6         11
#
#     DoP.year  DoA.day  DoA.month  DoA.year  Comment_TF  Answer_TF     Company
# 0       2022      NaN        NaN       NaN           1          0  voxenergie
# 1       2019      NaN        NaN       NaN           1          0  voxenergie
# 2       2019      NaN        NaN       NaN           1          0  voxenergie
# 3       2019      NaN        NaN       NaN           1          0  voxenergie
# 4       2023     18.0        7.0    2023.0           1          1  voxenergie
# 5       2022      NaN        NaN       NaN           1          0  voxenergie
# 6       2023     18.0        7.0    2023.0           1          1  voxenergie
# 7       2020      NaN        NaN       NaN           1          0  voxenergie
# 8       2022      NaN        NaN       NaN           1          0  voxenergie
# 9       2019      NaN        NaN       NaN           1          0  voxenergie
# 10      2021      NaN        NaN       NaN           1          0  voxenergie
# 11      2019      NaN        NaN       NaN           1          0  voxenergie
# 12      2023     18.0        7.0    2023.0           1          1  voxenergie
# 13      2023      NaN        NaN       NaN           1          0  voxenergie
# 14      2023      NaN        NaN       NaN           1          0  voxenergie
# 15      2022      NaN        NaN       NaN           1          0  voxenergie
# 16      2023      NaN        NaN       NaN           1          0  voxenergie
# 17      2019      NaN        NaN       NaN           1          0  voxenergie
# 18      2020      NaN        NaN       NaN           1          0  voxenergie
# 19      2019      NaN        NaN       NaN           1          0  voxenergie
#
# [20 rows x 22 columns]

# %%
#grünwelt energie
k=2
url1=(es_leq4000['comment'])[k]
company=(es_leq4000['supplier'])[k]
scrape_clean_save_v2(company,url1,sleep=False,start_page=1,end_page=0,suffix='page_1_to_infty')
# Out:
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\430334901.py:102: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
#                Nickname Location  Stars  \
# 0             T. Dohmen       DE      1
# 1              H. Wiche       DE      5
# 2                 Dadas       DE      1
# 3                 A. U.       DE      4
# 4                Beisel       DE      1
# ...                 ...      ...    ...
# 1870  Andreas Haverkamp       DE      2
# 1871    Patrick Rittau        DE      1
# 1872         Kurt Fries       DE      1
# 1873              nexas       DE      1
# 1874          tinolinoy       DE      5
#
#                                                Headline  \
# 0     Endabrechnung nicht innerhalb der gesetzlichen...
# 1         Schneller und reibungsloser Vertragsabschluss
# 2     Abschlussrechnung fehlt trotz mehreren Anfrage...
# 3               Die Daten für den Anbieterwechsel sind…
# 4                           Widerruf fast nicht möglich
# ...                                                 ...
# 1870  Gruenwelt ist teuer, ineffizient und nicht kor...
# 1871               Absolute FRECHHEIT unbedingt MEIDEN!
# 1872                      Unglaubliche Geschäftspraxis!
# 1873                Vorsicht! Vor Grünewelt und Stromio
# 1874                                  lohnender Wechsel
#
#                                   DoP        DoE  \
# 0           2023-08-31 11:45:33+00:00 2023-08-31
# 1           2023-08-31 13:01:37+00:00 2023-08-30
# 2           2023-08-31 13:09:27+00:00 2023-08-30
# 3           2023-08-11 19:01:32+00:00 2023-08-10
# 4           2023-09-01 13:34:40+00:00 2023-08-25
# ...                               ...        ...
# 1870        2018-04-26 11:36:38+00:00 2018-04-26
# 1871        2018-04-09 13:45:46+00:00 2018-04-09
# 1872 2017-01-24 08:36:25.910000+00:00 2017-01-24
# 1873        2016-10-05 18:06:27+00:00 2016-10-05
# 1874 2016-02-18 11:17:22.053000+00:00 2016-02-18
#
#                                                 Comment  \
# 0     Erfahrung mit Wärmestrom bei der Firma Grünwel...
# 1     Sehr gute Internetpräsenz. Alle wichtigen Info...
# 2     Ich warte jetzt seit über einen Monat auf mein...
# 3     Die Daten für den Anbieterwechsel sind schnell...
# 4     Ich habe einen Gasvertrag abgeschlossen und wo...
# ...                                                 ...
# 1870  2 nicht angekündigte Preiserhoehungen; in der ...
# 1871  Absolute FRECHHEIT unbedingt MEIDEN!Als unsere...
# 1872  Habe Strom und Gas bei Gruenwelt. Ich schreibe...
# 1873  Auch als Stromio bekannt: Lassen sich halt div...
# 1874  Ich habe mit diesem EVU sehr gute Erfahrungen ...
#
#                                                  Answer  \
# 0     Hallo T. Dohmen, wir bedauern, dass Sie bisher...
# 1     Hallo H. Wiche, vielen Dank für Ihre Bewertung...
# 2     Hallo Dadas, wir bedauern sehr, dass Sie auf I...
# 3     Hallo A. U., vielen Dank, dass Sie sich die Mü...
# 4     Hallo Beisel, wir bedauern sehr, dass Sie schl...
# ...                                                 ...
# 1870                                               None
# 1871                                               None
# 1872                                               None
# 1873                                               None
# 1874                                               None
#
#                            DoA  Page  ...  DoE.year  DoP.day  DoP.month  \
# 0    2023-09-04 06:41:52+00:00     1  ...      2023       31          8
# 1    2023-09-04 06:41:36+00:00     1  ...      2023       31          8
# 2    2023-09-04 06:41:13+00:00     1  ...      2023       31          8
# 3    2023-08-22 09:51:28+00:00     1  ...      2023       11          8
# 4    2023-08-30 07:15:04+00:00     1  ...      2023        1          9
# ...                        ...   ...  ...       ...      ...        ...
# 1870                       NaT    94  ...      2018       26          4
# 1871                       NaT    94  ...      2018        9          4
# 1872                       NaT    94  ...      2017       24          1
# 1873                       NaT    94  ...      2016        5         10
# 1874                       NaT    94  ...      2016       18          2
#
#       DoP.year  DoA.day  DoA.month  DoA.year  Comment_TF  Answer_TF  \
# 0         2023      4.0        9.0    2023.0           1          1
# 1         2023      4.0        9.0    2023.0           1          1
# 2         2023      4.0        9.0    2023.0           1          1
# 3         2023     22.0        8.0    2023.0           1          1
# 4         2023     30.0        8.0    2023.0           1          1
# ...        ...      ...        ...       ...         ...        ...
# 1870      2018      NaN        NaN       NaN           1          0
# 1871      2018      NaN        NaN       NaN           1          0
# 1872      2017      NaN        NaN       NaN           1          0
# 1873      2016      NaN        NaN       NaN           1          0
# 1874      2016      NaN        NaN       NaN           1          0
#
#                Company
# 0     Grünwelt Energie
# 1     Grünwelt Energie
# 2     Grünwelt Energie
# 3     Grünwelt Energie
# 4     Grünwelt Energie
# ...                ...
# 1870  Grünwelt Energie
# 1871  Grünwelt Energie
# 1872  Grünwelt Energie
# 1873  Grünwelt Energie
# 1874  Grünwelt Energie
#
# [1875 rows x 22 columns]

# %%
#EWE
k=7
url1=(es_leq4000['comment'])[k]
company=(es_leq4000['supplier'])[k]
scrape_clean_save_v2(company,url1,sleep=False,start_page=98,end_page=0,suffix='page_98_to_infty')
# Out:
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\773484398.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
#                Nickname Location  Stars  \
# 0       Benjamin Sommer       DE      2
# 1      Klaus aus Stelle       DE      5
# 2            Mike Daske       DE      5
# 3           Dieter Homp       DE      4
# 4                 Klach       DE      5
# ..                  ...      ...    ...
# 160        Hella Struth       DE      5
# 161         Antje Ebert       DE      4
# 162  Gerhard Roggenkamp       DE      3
# 163          Kemal Eker       DE      5
# 164        René Klünder       DE      5
#
#                                               Headline  \
# 0                                    Technische Mängel
# 1                                          Stromantrag
# 2    Einfache und Schnelle Antragstellung,übersicht...
# 3    Wenn man erstmal verstanden hat, wie  EWE sein...
# 4                                         Tippi, Toppi
# ..                                                 ...
# 160  Sehr gute Beratung. sehr freundlich alles bestens
# 161                                          bewertung
# 162  EWE ist im Vergleich zu anderen Anbietern zu t...
# 163                            Ewe ist das beste strom
# 164                                              SUPER
#
#                                  DoP        DoE  \
# 0          2016-10-10 14:15:44+00:00 2016-10-10
# 1          2016-10-10 12:29:17+00:00 2016-10-10
# 2          2016-10-10 12:27:14+00:00 2016-10-10
# 3          2016-10-10 11:56:56+00:00 2016-10-10
# 4          2016-10-06 15:21:41+00:00 2016-10-06
# ..                               ...        ...
# 160 2015-10-02 08:55:26.633000+00:00 2015-10-02
# 161 2015-09-24 18:16:39.942000+00:00 2015-09-24
# 162        2015-09-24 09:23:57+00:00 2015-09-24
# 163 2015-09-08 08:05:45.081000+00:00 2015-09-08
# 164        2012-06-07 17:53:11+00:00 2012-06-07
#
#                                                Comment  \
# 0    An sich eine gute Idee. Leider kommt es inbeso...
# 1    der Antrag für Strom läßt sich superleicht aus...
# 2    Internet Präsenz sehr gut. Leichte Antragstell...
# 3    Wenn man erstmal verstanden hat, wie EWE seine...
# 4          Vertragsänderung ohne Probleme erledigt!!!!
# ..                                                 ...
# 160         immer wieder arbeite ich gerne mit der EWE
# 161                         Alles gut und zu empfehlen
# 162  Ansonsten: Der Kundendiest ist freundlich und ...
# 163                                  Ewe ist das beste
# 164  Kompetente freundliche Beratung!!! Genaue Term...
#
#                                                 Answer  \
# 0    Moin Benjamin Sommer,ist sehr ärgerlich, dass ...
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 160                                               None
# 161                                               None
# 162  Sehr geehrter Herr Roggenkamp. Vielen Dank für...
# 163                                               None
# 164                                               None
#
#                                  DoA  Page  ...  DoE.year  DoP.day  DoP.month  \
# 0   2016-10-10 14:40:06.123000+00:00    98  ...      2016       10         10
# 1                                NaT    98  ...      2016       10         10
# 2                                NaT    98  ...      2016       10         10
# 3                                NaT    98  ...      2016       10         10
# 4                                NaT    98  ...      2016        6         10
# ..                               ...   ...  ...       ...      ...        ...
# 160                              NaT   106  ...      2015        2         10
# 161                              NaT   106  ...      2015       24          9
# 162 2015-09-30 10:53:19.218000+00:00   106  ...      2015       24          9
# 163                              NaT   106  ...      2015        8          9
# 164                              NaT   106  ...      2012        7          6
#
#      DoP.year  DoA.day  DoA.month  DoA.year  Comment_TF  Answer_TF  Company
# 0        2016     10.0       10.0    2016.0           1          1      EWE
# 1        2016      NaN        NaN       NaN           1          0      EWE
# 2        2016      NaN        NaN       NaN           1          0      EWE
# 3        2016      NaN        NaN       NaN           1          0      EWE
# 4        2016      NaN        NaN       NaN           1          0      EWE
# ..        ...      ...        ...       ...         ...        ...      ...
# 160      2015      NaN        NaN       NaN           1          0      EWE
# 161      2015      NaN        NaN       NaN           1          0      EWE
# 162      2015     30.0        9.0    2015.0           1          1      EWE
# 163      2015      NaN        NaN       NaN           1          0      EWE
# 164      2012      NaN        NaN       NaN           1          0      EWE
#
# [165 rows x 22 columns]

# %%
#Octopus energy
k=0
url1=(es_geq4000['comment'])[k]
company=(es_geq4000['supplier'])[k]
scrape_clean_save_v2(company,url1,sleep=False,start_page=37,end_page=0,suffix='_page_37_to_infty')
# Out:
# iteration stopped at page 37 and company Octopus Energy Germany
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 5
#       3 url1=(es_geq4000['comment'])[k]
#       4 company=(es_geq4000['supplier'])[k]
# ----> 5 scrape_clean_save_v2(company,url1,sleep=False,start_page=37,end_page=0,suffix='_page_37_to_infty')
#
# Cell In[74], line 87, in scrape_clean_save_v2(company, url1, sleep, start_page, end_page, suffix)
#      84         time.sleep(random_number) # add stop of random duration between 3-5 seconds
#      86 #Concatenate the list of DataFrames and reset index.
# ---> 87 df_concat=pd.concat(df)
#      88 df_concat.reset_index(inplace=True, drop=True)
#      90 #CLEAN--------------------------------------------------------------------------------------------------------------
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:368, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     146 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     147 def concat(
#     148     objs: Iterable[NDFrame] | Mapping[HashableT, NDFrame],
#    (...)
#     157     copy: bool = True,
#     158 ) -> DataFrame | Series:
#     159     """
#     160     Concatenate pandas objects along a particular axis.
#     161
#    (...)
#     366     1   3   4
#     367     """
# --> 368     op = _Concatenator(
#     369         objs,
#     370         axis=axis,
#     371         ignore_index=ignore_index,
#     372         join=join,
#     373         keys=keys,
#     374         levels=levels,
#     375         names=names,
#     376         verify_integrity=verify_integrity,
#     377         copy=copy,
#     378         sort=sort,
#     379     )
#     381     return op.get_result()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:425, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     422     objs = list(objs)
#     424 if len(objs) == 0:
# --> 425     raise ValueError("No objects to concatenate")
#     427 if keys is None:
#     428     objs = list(com.not_none(*objs))
#
# ValueError: No objects to concatenate

# %%
#E.ON energy
k=1
url1=(es_geq4000['comment'])[k]
company=(es_geq4000['supplier'])[k]
scrape_clean_save_v2(company,url1,sleep=True,start_page=312,end_page=0,suffix='page_312_to_infty')
# Out:
# C:\Users\isele\AppData\Local\Temp\ipykernel_16984\3136603813.py:98: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleaned['DoE.day']= df_cleaned['DoE.day'].str.replace('.', '')
#             Nickname Location  Stars  \
# 0             Wetzel       DE      5
# 1               güro       DE      1
# 2                Sch       DE      5
# 3              Roman       DE      1
# 4          Herr Rieß       DE      5
# ...              ...      ...    ...
# 6835  Herbert Beenen       DE      1
# 6836   Mustafa Özgür       DE      1
# 6837     Dirk Köster       DE      1
# 6838        Heiko H.       DE      1
# 6839      E. Neitzel       DE      1
#
#                                              Headline  \
# 0     Zählerstandsmeldung Es geht einfach und schnell
# 1                          Ein miserables Unternehmen
# 2                       Der Stromwechsel ging völlig…
# 3                  Antworten nicht auf Anfragen über…
# 4                         Sehr einfach in der Eingabe
# ...                                               ...
# 6835                           Mir hat nicht gefallen
# 6836            Das der versprochene Bonus nicht dem…
# 6837                              Aufgrund einer E.ON
# 6838            Ein sehr schlechter Service .Hotline…
# 6839                                Dreist und frech!
#
#                            DoP        DoE  \
# 0    2023-05-18 14:17:48+00:00 2023-05-17
# 1    2023-05-18 13:26:46+00:00 2023-05-18
# 2    2023-05-18 12:55:56+00:00 2023-05-17
# 3    2023-05-18 12:22:22+00:00 2023-04-29
# 4    2023-05-18 10:55:46+00:00 2023-05-15
# ...                        ...        ...
# 6835 2019-01-02 16:30:31+00:00 2019-01-02
# 6835          1  E.ON Energie Deutschland GmbH
# 6836          1  E.ON Energie Deutschland GmbH
# 6837          1  E.ON Energie Deutschland GmbH
# 6838          1  E.ON Energie Deutschland GmbH
# 6839          1  E.ON Energie Deutschland GmbH
#
# [6840 rows x 22 columns]

# %%
#MONTANA group
k=1
url1=(es_leq4000['comment'])[k]
company=(es_leq4000['supplier'])[k]
scrape_clean_save_v2(company,url1,sleep=False,start_page=1,end_page=52,suffix='page_53_to_infty')
# Out:
# iteration stopped at page 1 and company MONTANA Group
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[88], line 5
#       3 url1=(es_leq4000['comment'])[k]
#       4 company=(es_leq4000['supplier'])[k]
# ----> 5 scrape_clean_save_v2(company,url1,sleep=False,start_page=1,end_page=52,suffix='page_53_to_infty')
#
# Cell In[74], line 87, in scrape_clean_save_v2(company, url1, sleep, start_page, end_page, suffix)
#      84         time.sleep(random_number) # add stop of random duration between 3-5 seconds
#      86 #Concatenate the list of DataFrames and reset index.
# ---> 87 df_concat=pd.concat(df)
#      88 df_concat.reset_index(inplace=True, drop=True)
#      90 #CLEAN--------------------------------------------------------------------------------------------------------------
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:368, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     146 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     147 def concat(
#     148     objs: Iterable[NDFrame] | Mapping[HashableT, NDFrame],
#    (...)
#     157     copy: bool = True,
#     158 ) -> DataFrame | Series:
#     159     """
#     160     Concatenate pandas objects along a particular axis.
#     161
#    (...)
#     366     1   3   4
#     367     """
# --> 368     op = _Concatenator(
#     369         objs,
#     370         axis=axis,
#     371         ignore_index=ignore_index,
#     372         join=join,
#     373         keys=keys,
#     374         levels=levels,
#     375         names=names,
#     376         verify_integrity=verify_integrity,
#     377         copy=copy,
#     378         sort=sort,
#     379     )
#     381     return op.get_result()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:425, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     422     objs = list(objs)
#     424 if len(objs) == 0:
# --> 425     raise ValueError("No objects to concatenate")
#     427 if keys is None:
#     428     objs = list(com.not_none(*objs))
#
# ValueError: No objects to concatenate

# %% [markdown]
# ## Final Data Frame

# %%
display(es)
# Out:
#                              supplier                  city       country  \
# 0              Octopus Energy Germany               München   Deutschland
# 1                              Ostrom                Berlin   Deutschland
# 2                        Rabot Charge               Hamburg   Deutschland
# 3                       MONTANA Group              Grünwald   Deutschland
# 4       E.ON Energie Deutschland GmbH               München   Deutschland
# 5                    Grünwelt Energie                Kaarst   Deutschland
# 6                        RheinEnergie                  Köln   Deutschland
# 7                            badenova  Freiburg im Breisgau   Deutschland
# 8                        pricewise.de            Heidelberg   Deutschland
# 9                     DFM-Select GmbH             Metzingen   Deutschland
# 10       Vattenfall Europe Sales GmbH                   NaN           NaN
# 11                Erdgas Südwest GmbH             Ettlingen   Deutschland
# 12                           Zenstrom                Berlin   Deutschland
# 13                         VeganStrom                Berlin   Deutschland
# 14  Fair Trade Power Deutschland GmbH               München   Deutschland
# 15                Lekker Energie GmbH                Berlin   Deutschland
# 16                        Paketsparer                Berlin   Deutschland
# 17                        NEW Energie       Mönchengladbach   Deutschland
# 18                   SWK ENERGIE GmbH               Krefeld   Deutschland
# 19                          nowenergy                Berlin   Deutschland
# 20                           1KOMMA5°               Hamburg   Deutschland
# 21                        CHONO MEDIA                   NaN           NaN
# 22                       Fresh Energy                Berlin   Deutschland
# 23                 Polarstern Energie               München   Deutschland
# 24                         Primastrom                Berlin   Deutschland
# 25                        eprimo GmbH          Neu-Isenburg   Deutschland
# 26                         voxenergie                Berlin   Deutschland
# 27                     Lition Energie                Berlin   Deutschland
# 28                          Oekostrom                   NaN           NaN
# 29                          MEP Werke           Eckernförde   Deutschland
# 30                         LichtBlick               Hamburg   Deutschland
# 31                                RWE                 Essen   Deutschland
# 32                                EWE                   NaN           NaN
#
#                                                   cat  score  votes  \
# 0   Ökostromanbieter Energieanbieter Stromversorgu...    4.8   8042
# 18        https://de.trustpilot.com/review/www.swk.de
# 19  https://de.trustpilot.com/review/www.nowenergy.de
# 20   https://de.trustpilot.com/review/1komma5grad.com
# 21      https://de.trustpilot.com/review/www.chono.de
# 22   https://de.trustpilot.com/review/getfresh.energy
# 23  https://de.trustpilot.com/review/polarstern-en...
# 24     https://de.trustpilot.com/review/primastrom.de
# 25         https://de.trustpilot.com/review/eprimo.de
# 26  https://de.trustpilot.com/review/www.voxenergi...
# 27         https://de.trustpilot.com/review/lition.de
# 28     https://de.trustpilot.com/review/oekostrom.com
# 29      https://de.trustpilot.com/review/mep-werke.de
# 30     https://de.trustpilot.com/review/lichtblick.de
# 31        https://de.trustpilot.com/review/www.rwe.de
# 32        https://de.trustpilot.com/review/www.ewe.de

# %%
df=[]

for k in range(len(es)):
    company=(es['supplier'])[k]
    df.append(pd.read_csv('C:/Users/isele/OneDrive/Desktop/Supply Chain - Customer Satisfaction/Data/Concatenated Data/'+company+'.csv',index_col=0))

df_concat=pd.concat(df)
df_concat.reset_index(inplace=True, drop=True) 
df_concat.drop_duplicates(inplace=True)

# %%
len(df_concat)
# Out:
# 45180

# %%
display(df_concat)
# Out:
#                  Nickname Location  Stars  \
# 0                    Paul       DE      5
# 1                   Anton       DE      5
# 2                  Tobias       DE      5
# 3             Dirk Meinel       DE      5
# 4         Marianne Bäßler       DE      5
# ...                   ...      ...    ...
# 45175        Hella Struth       DE      5
# 45176         Antje Ebert       DE      4
# 45177  Gerhard Roggenkamp       DE      3
# 45178          Kemal Eker       DE      5
# 45179        René Klünder       DE      5
#
#                                                 Headline  \
# 0                                  Seriös und preiswert:
# 1                           Tarif mit vernünftigem Preis
# 2                                             Ringo Star
# 3                        Schritt für Schritt transparent
# 4                                     HOHE ZUFRIEDENHEIT
# ...                                                  ...
# 45175  Sehr gute Beratung. sehr freundlich alles bestens
# 45176                                          bewertung
# 45177  EWE ist im Vergleich zu anderen Anbietern zu t...
# 45178                            Ewe ist das beste strom
# 45179                                              SUPER
#
#                                     DoP         DoE  \
# 0             2023-08-29 15:00:29+00:00  2023-08-29
# 1             2023-08-30 11:20:02+00:00  2023-08-22
# 2             2023-08-29 10:00:40+00:00  2023-08-21
# 3             2023-08-30 09:18:07+00:00  2023-08-27
# 4             2023-08-29 17:30:02+00:00  2023-08-29
# ...                                 ...         ...
# 45175  2015-10-02 08:55:26.633000+00:00  2015-10-02
# 45176  2015-09-24 18:16:39.942000+00:00  2015-09-24
# 45177         2015-09-24 09:23:57+00:00  2015-09-24
# 45178  2015-09-08 08:05:45.081000+00:00  2015-09-08
# 45179         2012-06-07 17:53:11+00:00  2012-06-07
#
#                                                  Comment  \
# 0      Seriös und preiswert:nach einer ziemlich unang...
# 1      Tarif mit vernünftigem Preis bei niedrigem Ein...
# 2      Supi Anbieterwechsel,klappt alles mit dem vora...
# 3      Erstmalig habe ich mich bei Octopus Engergy an...
# 4      HOHE ZUFRIEDENHEIT BEIM NEUEN ANBIETER  OCTOPU...
# ...                                                  ...
# 45175         immer wieder arbeite ich gerne mit der EWE
# 45176                         Alles gut und zu empfehlen
# 45177  Ansonsten: Der Kundendiest ist freundlich und ...
# 45178                                  Ewe ist das beste
# 45179  Kompetente freundliche Beratung!!! Genaue Term...
#
#                                                   Answer  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 45175                                                NaN
# 45176                                                NaN
# 45177  Sehr geehrter Herr Roggenkamp. Vielen Dank für...
# 45178                                                NaN
# 45179                                                NaN
#
#                                     DoA  Page  ...  DoE.year  DoP.day  \
# 0                                   NaN     1  ...      2023       29
# 1                                   NaN     1  ...      2023       30
# 2                                   NaN     1  ...      2023       29
# 3                                   NaN     1  ...      2023       30
# 4                                   NaN     1  ...      2023       29
# ...                                 ...   ...  ...       ...      ...
# 45175                               NaN   106  ...      2015        2
# 45176                               NaN   106  ...      2015       24
# 45177  2015-09-30 10:53:19.218000+00:00   106  ...      2015       24
# 45178                               NaN   106  ...      2015        8
# 45179                               NaN   106  ...      2012        7
#
#        DoP.month  DoP.year  DoA.day  DoA.month  DoA.year  Comment_TF  \
# 0              8      2023      NaN        NaN       NaN           1
# 1              8      2023      NaN        NaN       NaN           1
# 2              8      2023      NaN        NaN       NaN           1
# 3              8      2023      NaN        NaN       NaN           1
# 4              8      2023      NaN        NaN       NaN           1
# ...          ...       ...      ...        ...       ...         ...
# 45175         10      2015      NaN        NaN       NaN           1
# 45176          9      2015      NaN        NaN       NaN           1
# 45177          9      2015     30.0        9.0    2015.0           1
# 45178          9      2015      NaN        NaN       NaN           1
# 45179          6      2012      NaN        NaN       NaN           1
#
#        Answer_TF                 Company
# 0              0  Octopus Energy Germany
# 1              0  Octopus Energy Germany
# 2              0  Octopus Energy Germany
# 3              0  Octopus Energy Germany
# 4              0  Octopus Energy Germany
# ...          ...                     ...
# 45175          0                     EWE
# 45176          0                     EWE
# 45177          1                     EWE
# 45178          0                     EWE
# 45179          0                     EWE
#
# [45180 rows x 22 columns]

# %%
df_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45180 entries, 0 to 45179
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Nickname    45178 non-null  object
#  1   Location    45180 non-null  object
#  2   Stars       45180 non-null  int64
#  3   Headline    45180 non-null  object
#  4   DoP         45180 non-null  object
#  5   DoE         45180 non-null  object
#  6   Comment     38931 non-null  object
#  7   Answer      28578 non-null  object
#  8   DoA         28578 non-null  object
#  9   Page        45180 non-null  int64
#  10  DoE.day     45180 non-null  int64
#  11  DoE.month   45180 non-null  int64
#  12  DoE.year    45180 non-null  int64
#  13  DoP.day     45180 non-null  int64
#  14  DoP.month   45180 non-null  int64
#  15  DoP.year    45180 non-null  int64
#  16  DoA.day     28578 non-null  float64
#  17  DoA.month   28578 non-null  float64
#  18  DoA.year    28578 non-null  float64
#  19  Comment_TF  45180 non-null  int64
#  20  Answer_TF   45180 non-null  int64
#  21  Company     45180 non-null  object
# dtypes: float64(3), int64(10), object(9)
# memory usage: 7.9+ MB

# %%
len(df_concat['DoP'].unique())
# Out:
# 45081

# %% [markdown]
# ### Save

# %%
df_concat.to_csv('C:/Users/isele/OneDrive/Desktop/Supply Chain - Customer Satisfaction/Data/all_suppliers_data.csv')
